# %%
import ipaddress
import networkx as nx
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import re
import pickle
import os

# %%
DD_THRESHOLD = 20
ARG_COVERAGE_THRESHOLD = 1
MCR_THRESHOLD = 0.1
AVG_DD_THRESHOLD = 0.6
AVG_MCR_THRESHOLD = 0.15
LOCAL_SUBNET = "163.194.0.0/16"
new_way = True

# %% [markdown]
# # Define Cluster

# %%
# Need to get cluster out to file, and save Hash GUID, List P2P read-later
# Pre-load cluster a part of, with time

cluster = {}
p2p_clusters = {}
list_p2p = set()
len_cluster = 0
num_clusters = 0

def clean():
    global cluster, p2p_clusters, list_p2p, len_cluster, num_clusters
    cluster = {}
    p2p_clusters = {}
    list_p2p = set()
    len_cluster = 0
    num_clusters = 0
    try:
        index = 0
        while True:
            if os.path.exists(f"out_cluster/clusters_{index}.pkl"):
                os.remove(f"out_cluster/clusters_{index}.pkl")
            else:
                break
            index += 1
    except Exception as e:
        print(f"Error removing old clusters: {e}")

# %%
clean()

# %%
import ipinfo_db
client = ipinfo_db.Client('')

# %% [markdown]
# # Read datatset

# %%
def find_cluster(flow_guid, num_clusters):
    # Check if saved clusters exist
    if not os.path.exists('out_cluster'):
        return None, -1
    
    for i in range(0, num_clusters-2):
        handle = open('out_cluster/cluster_{i}.pickle'.format(i=i), 'rb')
        cluster = pickle.load(handle)
        if flow_guid in cluster:
            handle.close()
            return cluster, i
        handle.close()
    return None, -1

def save_cluster(cluster, num_cluster):
    # Create directory if it doesn't exist
    if not os.path.exists('out_cluster'):
        os.makedirs('out_cluster')
    with open('out_cluster/cluster_{i}.pickle'.format(i=num_cluster), 'wb') as handle:
        pickle.dump(cluster, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
SRC_LABEL = "SrcAddr"
DST_LABEL = "DstAddr"
SPORT_LABEL = "Sport"
DPORT_LABEL = "Dport"
PROTO_LABEL = "Proto"
BPP_IN_LABEL = "BppIn"
BPP_OUT_LABEL = "BppOut"
G_BPP_IN_LABEL = "G_BppIn"
G_BPP_OUT_LABEL = "G_BppOut"

def define_index(line):
    l = re.split(r',|\n|\t', line)
    src_index, dst_index, proto_index, bpp_in_index, bpp_out_index, g_bpp_in_index, g_bpp_out_index = -1, -1, -1, -1, -1, -1, -1
    for i, v in enumerate(l):
        if v == SRC_LABEL:
            src_index = i
        elif v == DST_LABEL:
            dst_index = i
        elif v == PROTO_LABEL:
            proto_index = i
        elif v == BPP_IN_LABEL:
            bpp_in_index = i
        elif v == BPP_OUT_LABEL:
            bpp_out_index = i
        elif v == G_BPP_IN_LABEL:
            g_bpp_in_index = i
        elif v == G_BPP_OUT_LABEL:
            g_bpp_out_index = i
    return src_index, dst_index, proto_index, bpp_in_index, bpp_out_index, g_bpp_in_index, g_bpp_out_index

# %%
src_index, dst_index, proto_index, bpp_in_index, bpp_out_index, g_bpp_in_index, g_bpp_out_index = 0, 0, 0, 0, 0, 0, 0
with open('src/out_file/new_infile.csv') as f:
    new_way = True
    global cluster, p2p_clusters, list_p2p, len_cluster, num_clusters
    l_index = 0
    for line in f:
        # If first line (header)
        if (l_index == 0):
            src_index, dst_index, proto_index, bpp_in_index, bpp_out_index, g_bpp_in_index, g_bpp_out_index = define_index(line)
            l_index += 1
            continue
        
        # Split line into list
        l = re.split(r',|\n|\t', line)
        
        # Keep flow TCP and UDP only
        if (l[proto_index] != '6') and (l[proto_index] != '17'):
            continue
        
        temp_key = ()
        if new_way:
            temp_key = (l[src_index], l[proto_index], int(l[g_bpp_out_index]), int(l[g_bpp_in_index]),)
        else:
            temp_key = (l[src_index], l[proto_index], int(l[bpp_out_index]), int(l[bpp_in_index]),)
        
        # Generate GUID for flow
        flow_guid = hash(temp_key).__str__()

        temp_cluster = cluster
        cluster_filenum = -1
        
        # Add to cluster
        if flow_guid not in cluster:
            temp_cluster,cluster_filenum = find_cluster(flow_guid, num_clusters)
            if cluster_filenum == -1:
                temp_cluster = cluster
                temp_cluster[flow_guid] = dict(cls_def=temp_key, ddi=0, dd_set = set(), list_flows=[(l[dst_index],)])
                len_cluster += 1
        else:
            temp_cluster[flow_guid]['list_flows'].append((l[dst_index],))
            
        # Update DDI count
        if new_way:
            temp_cluster[flow_guid]['dd_set'].add(client.getASN(l[dst_index]))
        else:
            temp_cluster[flow_guid]['dd_set'].add(ipaddress.ip_network(l[dst_index]+'/16', strict= False).network_address)
        temp_cluster[flow_guid]['ddi'] = len(temp_cluster[flow_guid]['dd_set'])
        
        # Check if DDI meet threshold, then it is P2P
        if temp_cluster[flow_guid]['ddi'] >= DD_THRESHOLD:
            p2p_clusters[flow_guid] = temp_cluster[flow_guid]
            list_p2p.add(l[src_index])

        # Check if there is read outside of cluster
        if cluster_filenum != -1:
            save_cluster(temp_cluster, cluster_filenum)

        # Dump cluster to file
        if len_cluster % 2000000 == 0 and cluster_filenum == -1:
            save_cluster(cluster, num_clusters)
            cluster = {}
            num_clusters += 1
            print("Dumped clusters: ", num_clusters)
        
        # Increment line index
        l_index += 1
        if l_index % 500000 == 0:
            print("Processed: ", l_index)
# Out:
# Processed:  500000
# Processed:  1000000
# Processed:  1500000
# Processed:  2000000
# Processed:  2500000
# Processed:  3000000

# %%
# Iterate through p2p clusters
map_ip = {}
coverage = {}
remove_set = set()
for flow_guid, cluster in p2p_clusters.items():
    # Get the list of flows
    flows = cluster['list_flows']
    
    # Iterate through each flow
    for flow in flows:
        # Ignore local IPs
        if ipaddress.ip_address(flow[0]) not in ipaddress.ip_network(LOCAL_SUBNET, strict=False):
            asn = client.getASN(flow[0])
            map_ip[flow[0]] = asn
            if asn not in coverage:
                coverage[asn] = set()
            coverage[asn].add(cluster['cls_def'][0])

# COVERAGE_THRESHOLD = (1-(len(list_p2p)/len(map_ip)))*ARG_COVERAGE_THRESHOLD
COVERAGE_THRESHOLD = 0.6

# Re-iterate through p2p clusters to remove local IPs, also IP high coverage
for flow_guid, cluster in p2p_clusters.items():
    # Get the list of flows
    flows = cluster['list_flows']

    new_flows = []
    new_dd_set = set()
    
    # Iterate through each flow
    for flow in flows:
        # Get IP ASN
        asn = map_ip.get(flow[0])
        # Check coverage
        if asn is not None and len(coverage[asn])/len(list_p2p) >= COVERAGE_THRESHOLD:
            remove_set.add(flow[0])
            continue
        new_flows.append(flow)
        # new_dd_set.add(ipaddress.ip_network(flow[0]+'/16', strict= False).network_address)
        new_dd_set.add(client.getASN(flow[0]))
    # Update the cluster with the new flows
    cluster['list_flows'] = new_flows
    # Update the DDI count
    cluster['dd_set'] = new_dd_set
    cluster['ddi'] = len(new_dd_set)

# %% [markdown]
# # Community

# %%
# Calculate ddr_i that divide dd_i by the number of dest ip
def get_len_list_ip(flows):
    set_dsts = set()
    for dst in flows:
        set_dsts.add(dst[0])
    return set_dsts

def ddr_i(ddi, dsts):
    len_dsts = len(get_len_list_ip(dsts))
    if len_dsts == 0:
        return 0
    return ddi / len_dsts

# Given 2 cluster, if they have same stats, they are a pair, then calculate MCR of 2 clusters
def mcr(cluster1, cluster2):
    cls1= cluster1['cls_def']
    cls2=cluster2['cls_def']
    
    
    # print('Evaluate between ', cls1, ' and ', cls2)
    
    # 1 is proto, 2 is bpp_in, 3 is bpp_out
    if cls1[1] != cls2[1]:
        return 0
    if cls1[2] != cls2[2]:
        return 0
    if cls1[3] != cls2[3]:
        return 0
    
    # if cls2[2] == 0:
    #     if cls1[2] != 0:
    #         return 0
    # if cls2[3] == 0:
    #     if cls1[3] != 0:
    #         return 0
    
    # if cls2[2] != 0 and not (cls1[2] / cls2[2] > 0.75 and cls1[2] / cls2[2] < 1.25):
    #     return 0
    # if cls2[3] != 0 and not (cls1[3] / cls2[3] > 0.75 and cls1[3] / cls2[3] < 1.25):
    #     return 0
    
    ip_list_1 = get_len_list_ip(cluster1['list_flows'])
    ip_list_2 = get_len_list_ip(cluster2['list_flows'])
    intersection = len(ip_list_1.intersection(ip_list_2))
    union = len(ip_list_1.union(ip_list_2))
    
    if union == 0:
        return 0
    # print('Evaluate between ', cls1, ' and ', cls2, 'with MCR: ', intersection/union, intersection, union, len(ip_list_1), len(ip_list_2))
    return intersection / union

# Main construct graph function
def construct_graph(G, clusters, MCR_THRESHOLD=MCR_THRESHOLD):
    guid_tranversed = set()
    index = 0
    total_mcr = 0
    for guid, cls in clusters.items():
        index+=1
        G.add_node(guid, cls=cls,ddr_i=ddr_i(cls['ddi'], cls['list_flows']), cls_def=cls['cls_def'])
        if index % 100 == 0:
            total_mcr = 0
        guid_tranversed.add(guid)
        for guid_j,cls_j in clusters.items():
            if guid_j in guid_tranversed:
                continue
            mcr_ij = mcr(cls, cls_j)
            total_mcr += mcr_ij
            if mcr_ij > MCR_THRESHOLD:
                G.add_edge(guid, guid_j, mcr_ij=mcr_ij)
    return G
                
# Louvain community detection
def louvain_community_detection(G):
    return nx.community.louvain_communities(G, weight='mcr_ij')

# Clique detection for each community
def clique_detection(G, comm):
    temp_comm = comm.copy()
    list_bot = set()
    flag_exit = False
    while True:
        if len(temp_comm) < 3:
            break
        iterator = nx.clique.find_cliques(G.subgraph(temp_comm))
        set_vertex = set()
        index = 0
        while True:
            try:
                node = next(iterator)
                # print("Clique: ", node)
                if len(node) < 3:
                    if index == 0:
                        flag_exit = True
                    break
                for i in node:
                    set_vertex.add(i)
                    list_bot.add(G.nodes[i]['cls']['cls_def'][0])
                    # print("Add botnet: ", G.nodes[i]['cls']['cls_def'][0])
                index += 1
            except StopIteration:
                break
        temp_comm = temp_comm.difference(set_vertex)
        if flag_exit:
            break
    return list_bot

# Other way to evaluate, by examine degree of each node. 

# Evaluate community and output botnet list, include check comm mcr with threshold, cliques detection
def evaluate_community(G, comm_set, new_way=True, AVG_DD_THRESHOLD=AVG_DD_THRESHOLD, AVG_MCR_THRESHOLD=AVG_MCR_THRESHOLD):
    print('Evaluate community', len(comm_set))
    list_bot = set()
    bot_comm = []
    for comm in comm_set:
        total_ddri = 0
        if len(comm) == 0:
            continue
        for index in comm:
            total_ddri += G.nodes[index]['ddr_i']
        avg_ddri = total_ddri / len(comm)
        if avg_ddri < AVG_DD_THRESHOLD:
            # Implement no botnet flag
            continue
        
        total_mcr = 0
        edges = G.edges(comm)
        if len(edges) == 0:
            continue
        for edge in edges:
            total_mcr += G[edge[0]][edge[1]]['mcr_ij']
        avg_mcr = (2 * total_mcr) / (len(comm) * (len(comm)-1) )
        it = iter(comm)
        # print('Evaluate Community:', G.nodes[next(it)]['cls']['cls_def'], ', with avg_mcr:', avg_mcr, "avg_ddri:", avg_ddri)
        if avg_mcr < AVG_MCR_THRESHOLD:
            # Implement no botnet flag
            continue
        bot_comm.append(comm)
        
    print('Botnet community', len(bot_comm))
    
    if not new_way:
        for comm in bot_comm:
            for node in comm:
                list_bot.add(G.nodes[node]['cls']['cls_def'][0])
                # print("Add botnet: ", G.nodes[node]['cls']['cls_def'][0])
    else:    
        for comm in bot_comm:
            list_bot.update(clique_detection(G, comm))
        
    return list_bot

# %% [markdown]
# # Evaluate

# %%
ADDR_LABEL = "Addr"
TYPE_LABEL = "Type"

# Define mapping
mapping = set()
with_mapping = set()
mapper = {}

src_index, dst_index = 0, 0
with open('src/out_file/new_infile.csv') as f:
    l_index = 0
    for line in f:
        # If first line (header)
        if (l_index == 0):
            src_index, dst_index, _, _, _, _, _ = define_index(line)
            l_index += 1
            continue
        
        # Split line into list
        l = re.split(r',|\t|\n| ', line)
        mapping.add(l[src_index])
        mapping.add(l[dst_index])
        
addr_index, type_index = -1, -1
with open('../FullDS/bot_mapping.txt') as f:
    l_index = 0
    for line in f:
        l = re.split(r',|\n|\t| ', line)
        if (l_index == 0):
            for v in l:
                if v == ADDR_LABEL:
                    addr_index = l.index(v)
                elif v == TYPE_LABEL:
                    type_index = l.index(v)
            l_index += 1
            continue
        
        try:
            if ipaddress.ip_address(l[addr_index]):
                with_mapping.add(l[addr_index])
                if type_index != -1:
                    mapper[l[addr_index]] = l[type_index]
        except ValueError:
            print(f"Invalid IP address: {l[addr_index]}")
            pass
# Out:
# Invalid IP address:
# Invalid IP address:
# Invalid IP address:

# %%
def get_scores(flow_files, bots_ip_files, local_subnet, bots_set):
    # Define mapping
    mapping = set()
    info_bots = set()
    
    src_index, dst_index = 0, 0

    # Read file -> get all IPs
    if isinstance(flow_files, list) or isinstance(flow_files, set):
        for ip in flow_files:
            mapping.add(ip)
    else:
        with open(flow_files) as f:
            l_index = 0
            for line in f:
                # If first line (header)
                if (l_index == 0):
                    src_index, dst_index, _, _, _, _, _ = define_index(line)
                    l_index += 1
                    continue
                
                # Split line into list
                l = re.split(r',|\t|\n', line)
                mapping.add(l[src_index])
                mapping.add(l[dst_index])

    if isinstance(bots_ip_files, list) or isinstance(bots_ip_files, set):
        for ip in bots_ip_files:
            info_bots.add(ip)
    else:
        with open(bots_ip_files) as f:
            l_index = 0
            addr_index, type_index = 0, 0
            for line in f:
                l = re.split(r',|\n|\t| ', line)
                if (l_index == 0):
                    for v in l:
                        if v == ADDR_LABEL:
                            addr_index = l.index(v)
                        elif v == TYPE_LABEL:
                            type_index = l.index(v)
                    l_index += 1
                    continue
                
                try:
                    if ipaddress.ip_address(l[addr_index]):
                        info_bots.add(l[addr_index])
                except ValueError:
                    print(f"Invalid IP address: {l[addr_index]}")
                    pass

    temp_mapping = set(mapping)
    # Remove publics IP in mapping
    for ip in mapping:
        try:
            if ipaddress.ip_address(ip) not in ipaddress.ip_network(local_subnet, strict=False):
                temp_mapping.remove(ip)
        except ValueError:
            temp_mapping.remove(ip)
    mapping = temp_mapping
    
    # True Positive 
    number_tp_list = (info_bots.intersection(bots_set))
    number_tp = len(number_tp_list)

    # True Negative 
    number_tn_list = (mapping.difference(info_bots)).intersection(mapping.difference(bots_set))
    number_tn = len(number_tn_list)

    # False Positive 
    number_fp_list = (bots_set.difference(info_bots))
    number_fp = len(number_fp_list)

    # False Negative 
    number_fn_list = (info_bots.difference(bots_set))
    number_fn = len(number_fn_list)

    precision = number_tp / (number_tp + number_fp) if (number_tp + number_fp) != 0 else 0
    recall = number_tp / (number_tp + number_fn) if (number_tp + number_fn) != 0 else 0
    f1_score = 2 * (precision * recall) / (precision + recall) if (precision + recall) != 0 else 0

    return precision, recall, f1_score, [[number_tp, number_fp], [number_fn, number_tn]]

# %% [markdown]
# # Skopt

# %%
from sklearn.base import BaseEstimator, ClassifierMixin

class DetectSystem(BaseEstimator, ClassifierMixin):
    def __init__(self, DD=17, MCR=0.1, RM_POR =0.6, AVG_DD=0.1, AVG_MCR=0.1, new_way=True):
        self.DD = DD
        self.MCR = MCR
        self.RM_POR = RM_POR
        self.AVG_DD = AVG_DD
        self.AVG_MCR = AVG_MCR
        self.new_way = new_way

    # Build with X is mapping, 
    def fit(self, X, y):
        # Example: Store the training data
        self.X_ = X
        self.y_ = y
        # Training logic here
        return self
    
    def predict(self, X):
        global cluster, p2p_clusters, list_p2p, len_cluster, num_clusters
        # module_1_for_pr('INPUT/PeerRush.csv', new_way=self.new_way)
        # module_1('CTU/new_ctu_out.csv', new_way=self.new_way)
        # module_1('ISOT/new_ISOT.csv', new_way=self.new_way)

        # if self.new_way:
        #     # Remove same hosting
        #     remove_same_hosting(self.RM_POR)

        G = construct_graph(nx.Graph(), p2p_clusters, MCR_THRESHOLD=self.MCR)
        communities = louvain_community_detection(G)

        list_ip_bots = evaluate_community(G, communities, new_way=self.new_way, AVG_DD_THRESHOLD=self.AVG_DD, AVG_MCR_THRESHOLD=self.AVG_MCR)
        return list_ip_bots
    
    def clean():
        global cluster, p2p_clusters, list_p2p, len_cluster, num_clusters
        cluster = {}
        p2p_clusters = {}
        list_p2p = set()
        len_cluster = 0
        num_clusters = 0
        try:
            index = 0
            while True:
                if os.path.exists(f"clusters_{index}.pkl"):
                    os.remove(f"clusters_{index}.pkl")
                else:
                    break
                index += 1
        except Exception as e:
            print(f"Error removing old clusters: {e}")

# %%
from skopt.space import Real, Integer
from skopt.utils import use_named_args

space = [
    Real(0.001, 0.05, name='MCR'),
    Real(0.8, 1.0, name='AVG_DD'),
    Real(0.001, 0.1, name='AVG_MCR'),
]

@use_named_args(space)
def objective(**params):
    cls = DetectSystem(new_way=True, DD=17, RM_POR=0.6, **params)
    bots_list = cls.predict(X=None)
    all_scores = get_scores(mapping, with_mapping, LOCAL_SUBNET, bots_list)
    print("MCR: ", params['MCR'], "AVG_DD: ", params['AVG_DD'], "AVG_MCR: ", params['AVG_MCR'])
    # print("AVG_DD: ", params['AVG_DD'], "Scores: ", all_scores)
    print("Scores: ", all_scores)
    return -all_scores[2]

# %%
from skopt import gp_minimize
init_space = [0.001, 0.8, 0.07]
# init_space = [0.8]
init_scores = [objective(init_space)]
cls_gp = gp_minimize(objective, space, n_calls=500, n_jobs=-1, random_state=42, x0=init_space, y0=init_scores)
# Out:
# Evaluate community 124
# Botnet community 8
# MCR:  0.001 AVG_DD:  0.8 AVG_MCR:  0.07
# Scores:  (0.8878504672897196, 0.9595959595959596, 0.9223300970873787, [[95, 12], [4, 65425]])
# Evaluate community 147
# Botnet community 5
# MCR:  0.040030606356151424 AVG_DD:  0.8366869579732328 AVG_MCR:  0.07818940902700418
# Scores:  (0.8962264150943396, 0.9595959595959596, 0.926829268292683, [[95, 11], [4, 65426]])
# Evaluate community 145
# Botnet community 13
# MCR:  0.03024565773937787 AVG_DD:  0.8891665505707183 AVG_MCR:  0.01089751666598229
# Scores:  (0.9545454545454546, 0.8484848484848485, 0.8983957219251337, [[84, 4], [15, 65433]])
# Evaluate community 144
# Botnet community 16
# MCR:  0.023503195706327498 AVG_DD:  0.8667417222278044 AVG_MCR:  0.01514381497427214
# Scores:  (0.8867924528301887, 0.9494949494949495, 0.9170731707317074, [[94, 12], [5, 65425]])
# Evaluate community 146
# Botnet community 9
# MCR:  0.032893535174493796 AVG_DD:  0.8112823158054201 AVG_MCR:  0.07247787845441567
# Scores:  (0.8962264150943396, 0.9595959595959596, 0.926829268292683, [[95, 11], [4, 65426]])
# Evaluate community 148
# Botnet community 7
# MCR:  0.04698908274177177 AVG_DD:  0.8001557531682029 AVG_MCR:  0.09922894436983057
# Scores:  (0.8878504672897196, 0.9595959595959596, 0.9223300970873787, [[95, 12], [4, 65425]])
# Evaluate community 145
# Botnet community 10
# MCR:  0.03125659397175812 AVG_DD:  0.9223306320976562 AVG_MCR:  0.0016995642167520234
# Scores:  (0.9540229885057471, 0.8383838383838383, 0.8924731182795698, [[83, 4], [16, 65433]])
# Evaluate community 126
# Botnet community 10
# MCR:  0.0021300588270293723 AVG_DD:  0.9049549320516779 AVG_MCR:  0.040586236199810305
# Scores:  (0.9540229885057471, 0.8383838383838383, 0.8924731182795698, [[83, 4], [16, 65433]])
# Evaluate community 126
# Botnet community 0
# MCR:  0.0032866174974671564 AVG_DD:  0.9947511037682919 AVG_MCR:  0.024044362702600127
# Scores:  (0, 0.0, 0, [[0, 0], [99, 65437]])
# Evaluate community 130
# Botnet community 9
# MCR:  0.00543971529210822 AVG_DD:  0.9236772018666175 AVG_MCR:  0.038863737135449127
# Scores:  (0.9540229885057471, 0.8383838383838383, 0.8924731182795698, [[83, 4], [16, 65433]])
# Evaluate community 150
# Botnet community 2
# MCR:  0.04917831340453264 AVG_DD:  0.893352578649596 AVG_MCR:  0.08613410026689576
# Scores:  (1.0, 0.8383838383838383, 0.9120879120879121, [[83, 0], [16, 65437]])
# Evaluate community 150
# Botnet community 5
# MCR:  0.05 AVG_DD:  0.8535678741461896 AVG_MCR:  0.1
# Scores:  (0.8962264150943396, 0.9595959595959596, 0.926829268292683, [[95, 11], [4, 65426]])
# Evaluate community 124
# Botnet community 4
# MCR:  0.001 AVG_DD:  0.8234888936342006 AVG_MCR:  0.1
# Scores:  (0.9666666666666667, 0.8787878787878788, 0.9206349206349207, [[87, 3], [12, 65434]])
# Evaluate community 150
# Botnet community 19
# MCR:  0.05 AVG_DD:  0.8095927132124113 AVG_MCR:  0.001
# Scores:  (0.8636363636363636, 0.9595959595959596, 0.9090909090909092, [[95, 15], [4, 65422]])
# Evaluate community 150
# Botnet community 3
# MCR:  0.05 AVG_DD:  0.8680278772402029 AVG_MCR:  0.1
# Scores:  (0.9215686274509803, 0.9494949494949495, 0.9353233830845771, [[94, 8], [5, 65429]])
# Evaluate community 124
# Botnet community 2
# MCR:  0.001 AVG_DD:  0.8730461900652041 AVG_MCR:  0.1
# Scores:  (1.0, 0.8383838383838383, 0.9120879120879121, [[83, 0], [16, 65437]])
# Evaluate community 150
# Botnet community 5
# MCR:  0.05 AVG_DD:  0.8467845859220431 AVG_MCR:  0.1
# Scores:  (0.8962264150943396, 0.9595959595959596, 0.926829268292683, [[95, 11], [4, 65426]])
# Evaluate community 150
# Botnet community 4
# MCR:  0.05 AVG_DD:  0.8627920365191463 AVG_MCR:  0.1
# Scores:  (0.8952380952380953, 0.9494949494949495, 0.9215686274509803, [[94, 11], [5, 65426]])
# Evaluate community 150
# Botnet community 6
# MCR:  0.04999347836973819 AVG_DD:  0.8278889491927202 AVG_MCR:  0.09773168745572475
# Scores:  (0.8962264150943396, 0.9595959595959596, 0.926829268292683, [[95, 11], [4, 65426]])
# Evaluate community 149
# Botnet community 0
# MCR:  0.048828945411033074 AVG_DD:  0.9125685143947345 AVG_MCR:  0.09579476185068085
# Scores:  (0, 0.0, 0, [[0, 0], [99, 65437]])
# Evaluate community 146
# Botnet community 6
# MCR:  0.0373813305208773 AVG_DD:  0.8486891261098796 AVG_MCR:  0.07581074819708639
# Scores:  (0.8962264150943396, 0.9595959595959596, 0.926829268292683, [[95, 11], [4, 65426]])
# Evaluate community 126
# Botnet community 16
# MCR:  0.002106172177904155 AVG_DD:  0.8549933523175881 AVG_MCR:  0.013109019836183282
# Scores:  (0.8545454545454545, 0.9494949494949495, 0.8995215311004785, [[94, 16], [5, 65421]])
# Evaluate community 150
# Botnet community 6
# MCR:  0.05 AVG_DD:  0.8277497042361304 AVG_MCR:  0.09804036859836447
# Scores:  (0.8962264150943396, 0.9595959595959596, 0.926829268292683, [[95, 11], [4, 65426]])
# Evaluate community 148
# Botnet community 1
# MCR:  0.04558456989486787 AVG_DD:  0.9030936781609196 AVG_MCR:  0.08160602796593493
# Scores:  (0, 0.0, 0, [[0, 0], [99, 65437]])
# Evaluate community 150
# Botnet community 0
# MCR:  0.0496116708456165 AVG_DD:  0.9229805253419452 AVG_MCR:  0.07762174554267895
# Scores:  (0, 0.0, 0, [[0, 0], [99, 65437]])
# Evaluate community 146
# Botnet community 7
# MCR:  0.038453255740679815 AVG_DD:  0.8272386222019306 AVG_MCR:  0.07765128633768226
# Scores:  (0.8962264150943396, 0.9595959595959596, 0.926829268292683, [[95, 11], [4, 65426]])
# Evaluate community 150
# Botnet community 2
# MCR:  0.05 AVG_DD:  0.8845867152285601 AVG_MCR:  0.08687277724249531
# Scores:  (1.0, 0.8383838383838383, 0.9120879120879121, [[83, 0], [16, 65437]])
# Evaluate community 130
# Botnet community 17
# MCR:  0.006834581371236034 AVG_DD:  0.8459134469692282 AVG_MCR:  0.0056828612271636325
# Scores:  (0.8545454545454545, 0.9494949494949495, 0.8995215311004785, [[94, 16], [5, 65421]])
# Evaluate community 150
# Botnet community 6
# MCR:  0.05 AVG_DD:  0.809805941348999 AVG_MCR:  0.09756311948149451
# Scores:  (0.8962264150943396, 0.9595959595959596, 0.926829268292683, [[95, 11], [4, 65426]])
# Evaluate community 146
# Botnet community 7
# MCR:  0.035126050515190264 AVG_DD:  0.8378972437813117 AVG_MCR:  0.07498210976823824
# Scores:  (0.8962264150943396, 0.9595959595959596, 0.926829268292683, [[95, 11], [4, 65426]])
# Evaluate community 148
# Botnet community 0
# MCR:  0.04440281977089953 AVG_DD:  1.0 AVG_MCR:  0.04791351199094278
# Scores:  (0, 0.0, 0, [[0, 0], [99, 65437]])
# Evaluate community 147
# Botnet community 8
# MCR:  0.04299315132562532 AVG_DD:  0.8246191678400484 AVG_MCR:  0.0712942558773953
# Scores:  (0.8962264150943396, 0.9595959595959596, 0.926829268292683, [[95, 11], [4, 65426]])
# Evaluate community 131
# Botnet community 12
# MCR:  0.00844680875533633 AVG_DD:  0.8814753859853247 AVG_MCR:  0.038840349286679086
# Scores:  (0.9550561797752809, 0.8585858585858586, 0.9042553191489363, [[85, 4], [14, 65433]])
# Evaluate community 146
# Botnet community 16
# MCR:  0.03667016879954361 AVG_DD:  0.8583340880891288 AVG_MCR:  0.0019008100192194196
# Scores:  (0.8623853211009175, 0.9494949494949495, 0.9038461538461539, [[94, 15], [5, 65422]])
# Evaluate community 147
# Botnet community 12
# MCR:  0.039552592186386314 AVG_DD:  0.9110983034107719 AVG_MCR:  0.005895670019733102
# Scores:  (0.9540229885057471, 0.8383838383838383, 0.8924731182795698, [[83, 4], [16, 65433]])
# Evaluate community 146
# Botnet community 7
# MCR:  0.032287624179240505 AVG_DD:  0.8 AVG_MCR:  0.08129466504329591
# Scores:  (0.8878504672897196, 0.9595959595959596, 0.9223300970873787, [[95, 12], [4, 65425]])
# Evaluate community 150
# Botnet community 7
# MCR:  0.04951516030414379 AVG_DD:  0.8 AVG_MCR:  0.08441336825157608
# Scores:  (0.8878504672897196, 0.9595959595959596, 0.9223300970873787, [[95, 12], [4, 65425]])
# Evaluate community 124
# Botnet community 12
# MCR:  0.001 AVG_DD:  0.9012698660562974 AVG_MCR:  0.025545775443595993
# Scores:  (0.9550561797752809, 0.8585858585858586, 0.9042553191489363, [[85, 4], [14, 65433]])
# Evaluate community 150
# Botnet community 2
# MCR:  0.05 AVG_DD:  0.8909008826746526 AVG_MCR:  0.08683225302379026
# Scores:  (1.0, 0.8383838383838383, 0.9120879120879121, [[83, 0], [16, 65437]])
# Evaluate community 144
# Botnet community 18
# MCR:  0.02370521883786486 AVG_DD:  0.8 AVG_MCR:  0.02567847457834114
# Scores:  (0.8636363636363636, 0.9595959595959596, 0.9090909090909092, [[95, 15], [4, 65422]])
# Evaluate community 125
# Botnet community 14
# MCR:  0.0018023470838790059 AVG_DD:  0.8769959264201755 AVG_MCR:  0.025760056664849314
# Scores:  (0.9550561797752809, 0.8585858585858586, 0.9042553191489363, [[85, 4], [14, 65433]])
# Evaluate community 147
# Botnet community 18
# MCR:  0.040968490352086565 AVG_DD:  0.8330689531458797 AVG_MCR:  0.018995413795904467
# Scores:  (0.8636363636363636, 0.9595959595959596, 0.9090909090909092, [[95, 15], [4, 65422]])
# Evaluate community 148
# Botnet community 17
# MCR:  0.04832450165083512 AVG_DD:  0.8 AVG_MCR:  0.022457744883184746
# Scores:  (0.8558558558558559, 0.9595959595959596, 0.9047619047619048, [[95, 16], [4, 65421]])
# Evaluate community 124
# Botnet community 10
# MCR:  0.001 AVG_DD:  0.9232093322104002 AVG_MCR:  0.027391612514876727
# Scores:  (0.9540229885057471, 0.8383838383838383, 0.8924731182795698, [[83, 4], [16, 65433]])
# Evaluate community 147
# Botnet community 11
# MCR:  0.043133615122946056 AVG_DD:  0.882801840941661 AVG_MCR:  0.031682177309560904
# Scores:  (0.9540229885057471, 0.8383838383838383, 0.8924731182795698, [[83, 4], [16, 65433]])
# Evaluate community 147
# Botnet community 2
# MCR:  0.04204975457997552 AVG_DD:  0.8896930855999342 AVG_MCR:  0.09151538580168864
# Scores:  (1.0, 0.8383838383838383, 0.9120879120879121, [[83, 0], [16, 65437]])
# Evaluate community 124
# Botnet community 12
# MCR:  0.001 AVG_DD:  0.9063736232123369 AVG_MCR:  0.030240234098642522
# Scores:  (0.9550561797752809, 0.8585858585858586, 0.9042553191489363, [[85, 4], [14, 65433]])
# Evaluate community 150
# Botnet community 3
# MCR:  0.05 AVG_DD:  0.868390989470972 AVG_MCR:  0.08295869233586654
# Scores:  (0.9215686274509803, 0.9494949494949495, 0.9353233830845771, [[94, 8], [5, 65429]])
# Evaluate community 147
# Botnet community 5
# MCR:  0.03954536588248825 AVG_DD:  0.8756088848887429 AVG_MCR:  0.06808950070064292
# Scores:  (1.0, 0.8383838383838383, 0.9120879120879121, [[83, 0], [16, 65437]])
# Evaluate community 134
# Botnet community 15
# MCR:  0.011021715280183652 AVG_DD:  0.8093212149766266 AVG_MCR:  0.039526978654110194
# Scores:  (0.8558558558558559, 0.9595959595959596, 0.9047619047619048, [[95, 16], [4, 65421]])
# Evaluate community 124
# Botnet community 11
# MCR:  0.001 AVG_DD:  0.8948299247054947 AVG_MCR:  0.03868771936504538
# Scores:  (0.9540229885057471, 0.8383838383838383, 0.8924731182795698, [[83, 4], [16, 65433]])
# Evaluate community 150
# Botnet community 6
# MCR:  0.05 AVG_DD:  0.8620179078747662 AVG_MCR:  0.06983985476351016
# Scores:  (0.8952380952380953, 0.9494949494949495, 0.9215686274509803, [[94, 11], [5, 65426]])
# Evaluate community 150
# Botnet community 2
# MCR:  0.05 AVG_DD:  0.8884207281912436 AVG_MCR:  0.07887188731439479
# Scores:  (1.0, 0.8383838383838383, 0.9120879120879121, [[83, 0], [16, 65437]])
# Evaluate community 150
# Botnet community 2
# MCR:  0.04908543600421641 AVG_DD:  0.8870136081861577 AVG_MCR:  0.1
# Scores:  (1.0, 0.8383838383838383, 0.9120879120879121, [[83, 0], [16, 65437]])
# Evaluate community 147
# Botnet community 2
# MCR:  0.04127034503661008 AVG_DD:  0.8863819966952359 AVG_MCR:  0.0900652885046948
# Scores:  (1.0, 0.8383838383838383, 0.9120879120879121, [[83, 0], [16, 65437]])
# Evaluate community 148
# Botnet community 6
# MCR:  0.044915231714147956 AVG_DD:  0.815288602646328 AVG_MCR:  0.1
# Scores:  (0.8962264150943396, 0.9595959595959596, 0.926829268292683, [[95, 11], [4, 65426]])
# Evaluate community 147
# Botnet community 5
# MCR:  0.03963693229569908 AVG_DD:  0.8523270847020648 AVG_MCR:  0.1
# Scores:  (0.8962264150943396, 0.9595959595959596, 0.926829268292683, [[95, 11], [4, 65426]])
# Evaluate community 146
# Botnet community 11
# MCR:  0.03667650309859547 AVG_DD:  0.831718804108123 AVG_MCR:  0.05232123046037387
# Scores:  (0.8636363636363636, 0.9595959595959596, 0.9090909090909092, [[95, 15], [4, 65422]])
# Evaluate community 150
# Botnet community 6
# MCR:  0.05 AVG_DD:  0.817083501317927 AVG_MCR:  0.08197869298993314
# Scores:  (0.8962264150943396, 0.9595959595959596, 0.926829268292683, [[95, 11], [4, 65426]])
# Evaluate community 126
# Botnet community 19
# MCR:  0.0024083205237139275 AVG_DD:  0.8216690422658205 AVG_MCR:  0.001
# Scores:  (0.8558558558558559, 0.9595959595959596, 0.9047619047619048, [[95, 16], [4, 65421]])
# Evaluate community 146
# Botnet community 12
# MCR:  0.03758098140372879 AVG_DD:  0.9067358497284022 AVG_MCR:  0.001
# Scores:  (0.9540229885057471, 0.8383838383838383, 0.8924731182795698, [[83, 4], [16, 65433]])
# Evaluate community 146
# Botnet community 5
# MCR:  0.03826426430557298 AVG_DD:  0.8377188258822198 AVG_MCR:  0.1
# Scores:  (0.8962264150943396, 0.9595959595959596, 0.926829268292683, [[95, 11], [4, 65426]])
# Evaluate community 130
# Botnet community 8
# MCR:  0.007487958320271829 AVG_DD:  0.9312418391240299 AVG_MCR:  0.02931371655342384
# Scores:  (0.9540229885057471, 0.8383838383838383, 0.8924731182795698, [[83, 4], [16, 65433]])
# Evaluate community 147
# Botnet community 6
# MCR:  0.04251319693596536 AVG_DD:  0.8086269558702133 AVG_MCR:  0.1
# Scores:  (0.8962264150943396, 0.9595959595959596, 0.926829268292683, [[95, 11], [4, 65426]])
# Evaluate community 124
# Botnet community 12
# MCR:  0.001 AVG_DD:  0.8673045333659215 AVG_MCR:  0.04332535428183872
# Scores:  (0.8545454545454545, 0.9494949494949495, 0.8995215311004785, [[94, 16], [5, 65421]])
# Evaluate community 124
# Botnet community 14
# MCR:  0.001 AVG_DD:  0.873797288970356 AVG_MCR:  0.001
# Scores:  (0.9550561797752809, 0.8585858585858586, 0.9042553191489363, [[85, 4], [14, 65433]])
# Evaluate community 146
# Botnet community 6
# MCR:  0.032182321781521445 AVG_DD:  0.8342827876156982 AVG_MCR:  0.1
# Scores:  (0.8962264150943396, 0.9595959595959596, 0.926829268292683, [[95, 11], [4, 65426]])
# Evaluate community 124
# Botnet community 6
# MCR:  0.001 AVG_DD:  0.8873976449217322 AVG_MCR:  0.0612249533562511
# Scores:  (0.9540229885057471, 0.8383838383838383, 0.8924731182795698, [[83, 4], [16, 65433]])
# Evaluate community 145
# Botnet community 6
# MCR:  0.02959235593302515 AVG_DD:  0.8126890471602313 AVG_MCR:  0.1
# Scores:  (0.8962264150943396, 0.9595959595959596, 0.926829268292683, [[95, 11], [4, 65426]])
# Evaluate community 145
# Botnet community 13
# MCR:  0.028128191225155877 AVG_DD:  0.8454087245354673 AVG_MCR:  0.0484959238887438
# Scores:  (0.8636363636363636, 0.9595959595959596, 0.9090909090909092, [[95, 15], [4, 65422]])
# Evaluate community 124
# Botnet community 2
# MCR:  0.001 AVG_DD:  0.8667762442725402 AVG_MCR:  0.09083140093879162
# Scores:  (1.0, 0.8383838383838383, 0.9120879120879121, [[83, 0], [16, 65437]])
# Evaluate community 150
# Botnet community 2
# MCR:  0.05 AVG_DD:  0.8693320402191296 AVG_MCR:  0.07566698224523219
# Scores:  (1.0, 0.8383838383838383, 0.9120879120879121, [[83, 0], [16, 65437]])
# Evaluate community 150
# Botnet community 8
# MCR:  0.05 AVG_DD:  0.8557336999831314 AVG_MCR:  0.06130728654700186
# Scores:  (0.8962264150943396, 0.9595959595959596, 0.926829268292683, [[95, 11], [4, 65426]])
# Evaluate community 150
# Botnet community 2
# MCR:  0.05 AVG_DD:  0.8708022887490946 AVG_MCR:  0.08736780106414012
# Scores:  (1.0, 0.8383838383838383, 0.9120879120879121, [[83, 0], [16, 65437]])
# Evaluate community 150
# Botnet community 16
# MCR:  0.05 AVG_DD:  0.8218713089052657 AVG_MCR:  0.0335670641465554
# Scores:  (0.8636363636363636, 0.9595959595959596, 0.9090909090909092, [[95, 15], [4, 65422]])
# Evaluate community 150
# Botnet community 9
# MCR:  0.05 AVG_DD:  0.817573339941692 AVG_MCR:  0.06025982054695019
# Scores:  (0.8962264150943396, 0.9595959595959596, 0.926829268292683, [[95, 11], [4, 65426]])
# Evaluate community 150
# Botnet community 19
# MCR:  0.05 AVG_DD:  0.8343925197341173 AVG_MCR:  0.001
# Scores:  (0.8636363636363636, 0.9595959595959596, 0.9090909090909092, [[95, 15], [4, 65422]])
# Evaluate community 133
# Botnet community 0
# MCR:  0.009538178585246842 AVG_DD:  0.9122849419671273 AVG_MCR:  0.1
# Scores:  (0, 0.0, 0, [[0, 0], [99, 65437]])
# Evaluate community 150
# Botnet community 7
# MCR:  0.05 AVG_DD:  0.8783731912917694 AVG_MCR:  0.05592051310599634
# Scores:  (0.9540229885057471, 0.8383838383838383, 0.8924731182795698, [[83, 4], [16, 65433]])
# Evaluate community 150
# Botnet community 13
# MCR:  0.05 AVG_DD:  0.859586186107638 AVG_MCR:  0.03872741589875518
# Scores:  (0.8623853211009175, 0.9494949494949495, 0.9038461538461539, [[94, 15], [5, 65422]])
# Evaluate community 150
# Botnet community 7
# MCR:  0.05 AVG_DD:  0.9398727262886685 AVG_MCR:  0.001
# Scores:  (0.9540229885057471, 0.8383838383838383, 0.8924731182795698, [[83, 4], [16, 65433]])
# Evaluate community 150
# Botnet community 5
# MCR:  0.05 AVG_DD:  0.8541601127359695 AVG_MCR:  0.07938038760543928
# Scores:  (0.8962264150943396, 0.9595959595959596, 0.926829268292683, [[95, 11], [4, 65426]])
# Evaluate community 124
# Botnet community 5
# MCR:  0.001 AVG_DD:  0.8053091662474576 AVG_MCR:  0.07955572340352
# Scores:  (0.9666666666666667, 0.8787878787878788, 0.9206349206349207, [[87, 3], [12, 65434]])
# Evaluate community 150
# Botnet community 5
# MCR:  0.05 AVG_DD:  0.8425248596272464 AVG_MCR:  0.08469118375292596
# Scores:  (0.8962264150943396, 0.9595959595959596, 0.926829268292683, [[95, 11], [4, 65426]])
# Evaluate community 135
# Botnet community 4
# MCR:  0.014512477904870737 AVG_DD:  0.9524188839806428 AVG_MCR:  0.001
# Scores:  (0.9534883720930233, 0.8282828282828283, 0.8864864864864866, [[82, 4], [17, 65433]])
# Evaluate community 124
# Botnet community 3
# MCR:  0.001 AVG_DD:  0.9541526881841911 AVG_MCR:  0.03750912453696507
# Scores:  (0.95, 0.7676767676767676, 0.8491620111731844, [[76, 4], [23, 65433]])
# Evaluate community 124
# Botnet community 18
# MCR:  0.001 AVG_DD:  0.8151877287024832 AVG_MCR:  0.015530588130437124
# Scores:  (0.8558558558558559, 0.9595959595959596, 0.9047619047619048, [[95, 16], [4, 65421]])
# Evaluate community 150
# Botnet community 12
# MCR:  0.05 AVG_DD:  0.8 AVG_MCR:  0.04837505830840343
# Scores:  (0.8558558558558559, 0.9595959595959596, 0.9047619047619048, [[95, 16], [4, 65421]])
# Evaluate community 150
# Botnet community 8
# MCR:  0.05 AVG_DD:  0.931334883413902 AVG_MCR:  0.001
# Scores:  (0.9540229885057471, 0.8383838383838383, 0.8924731182795698, [[83, 4], [16, 65433]])
# Evaluate community 124
# Botnet community 13
# MCR:  0.001 AVG_DD:  0.8838394260746949 AVG_MCR:  0.001
# Scores:  (0.9550561797752809, 0.8585858585858586, 0.9042553191489363, [[85, 4], [14, 65433]])
# Evaluate community 150
# Botnet community 16
# MCR:  0.05 AVG_DD:  0.8394366150516955 AVG_MCR:  0.026174100133467687
# Scores:  (0.8636363636363636, 0.9595959595959596, 0.9090909090909092, [[95, 15], [4, 65422]])
# Evaluate community 124
# Botnet community 0
# MCR:  0.001 AVG_DD:  0.9630823438334057 AVG_MCR:  0.1
# Scores:  (0, 0.0, 0, [[0, 0], [99, 65437]])
# Evaluate community 135
# Botnet community 4
# MCR:  0.01465999871489753 AVG_DD:  0.9481501782442189 AVG_MCR:  0.02073625750545061
# Scores:  (0.9534883720930233, 0.8282828282828283, 0.8864864864864866, [[82, 4], [17, 65433]])
# Evaluate community 124
# Botnet community 19
# MCR:  0.001 AVG_DD:  0.8 AVG_MCR:  0.001
# Scores:  (0.8558558558558559, 0.9595959595959596, 0.9047619047619048, [[95, 16], [4, 65421]])
# Evaluate community 143
# Botnet community 14
# MCR:  0.022667674658247906 AVG_DD:  0.893883112057995 AVG_MCR:  0.001
# Scores:  (0.9550561797752809, 0.8585858585858586, 0.9042553191489363, [[85, 4], [14, 65433]])
# Evaluate community 150
# Botnet community 16
# MCR:  0.05 AVG_DD:  0.8660487423314439 AVG_MCR:  0.001
# Scores:  (0.8867924528301887, 0.9494949494949495, 0.9170731707317074, [[94, 12], [5, 65425]])
# Evaluate community 148
# Botnet community 2
# MCR:  0.0440548150454168 AVG_DD:  0.9584123100062972 AVG_MCR:  0.012803982286300645
# Scores:  (1.0, 0.7676767676767676, 0.8685714285714284, [[76, 0], [23, 65437]])
# Evaluate community 150
# Botnet community 2
# MCR:  0.05 AVG_DD:  0.8808024052979605 AVG_MCR:  0.1
# Scores:  (1.0, 0.8383838383838383, 0.9120879120879121, [[83, 0], [16, 65437]])
# Evaluate community 124
# Botnet community 11
# MCR:  0.001 AVG_DD:  0.8234090304244976 AVG_MCR:  0.0548137085510071
# Scores:  (0.8558558558558559, 0.9595959595959596, 0.9047619047619048, [[95, 16], [4, 65421]])
# Evaluate community 150
# Botnet community 6
# MCR:  0.05 AVG_DD:  0.8227785303393614 AVG_MCR:  0.08354523611428744
# Scores:  (0.8962264150943396, 0.9595959595959596, 0.926829268292683, [[95, 11], [4, 65426]])
# Evaluate community 150
# Botnet community 10
# MCR:  0.05 AVG_DD:  0.8388199545596311 AVG_MCR:  0.05546854297648301
# Scores:  (0.8636363636363636, 0.9595959595959596, 0.9090909090909092, [[95, 15], [4, 65422]])
# Evaluate community 150
# Botnet community 9
# MCR:  0.05 AVG_DD:  0.8513181797964763 AVG_MCR:  0.05870100153811917
# Scores:  (0.8962264150943396, 0.9595959595959596, 0.926829268292683, [[95, 11], [4, 65426]])
# Evaluate community 124
# Botnet community 10
# MCR:  0.001 AVG_DD:  0.8131705342592024 AVG_MCR:  0.05704405350182706
# Scores:  (0.8558558558558559, 0.9595959595959596, 0.9047619047619048, [[95, 16], [4, 65421]])
# Evaluate community 124
# Botnet community 18
# MCR:  0.001 AVG_DD:  0.806057842054069 AVG_MCR:  0.017888182372332504
# Scores:  (0.8558558558558559, 0.9595959595959596, 0.9047619047619048, [[95, 16], [4, 65421]])
# Evaluate community 150
# Botnet community 6
# MCR:  0.05 AVG_DD:  0.831978567445307 AVG_MCR:  0.08676943860197925
# Scores:  (0.8962264150943396, 0.9595959595959596, 0.926829268292683, [[95, 11], [4, 65426]])
# Evaluate community 150
# Botnet community 19
# MCR:  0.05 AVG_DD:  0.8281864181442062 AVG_MCR:  0.001
# Scores:  (0.8636363636363636, 0.9595959595959596, 0.9090909090909092, [[95, 15], [4, 65422]])
# Evaluate community 150
# Botnet community 14
# MCR:  0.05 AVG_DD:  0.851301629446662 AVG_MCR:  0.03771332918122557
# Scores:  (0.8636363636363636, 0.9595959595959596, 0.9090909090909092, [[95, 15], [4, 65422]])
# Evaluate community 124
# Botnet community 4
# MCR:  0.001 AVG_DD:  0.8119534193291693 AVG_MCR:  0.0851359492750288
# Scores:  (0.9666666666666667, 0.8787878787878788, 0.9206349206349207, [[87, 3], [12, 65434]])
# Evaluate community 150
# Botnet community 7
# MCR:  0.05 AVG_DD:  0.8193589316647681 AVG_MCR:  0.0710652624057748
# Scores:  (0.8962264150943396, 0.9595959595959596, 0.926829268292683, [[95, 11], [4, 65426]])
# Evaluate community 124
# Botnet community 5
# MCR:  0.001 AVG_DD:  0.8917011746839023 AVG_MCR:  0.07308320314667607
# Scores:  (1.0, 0.8383838383838383, 0.9120879120879121, [[83, 0], [16, 65437]])
# Evaluate community 150
# Botnet community 9
# MCR:  0.05 AVG_DD:  0.805197658458088 AVG_MCR:  0.0617988307134773
# Scores:  (0.8962264150943396, 0.9595959595959596, 0.926829268292683, [[95, 11], [4, 65426]])
# Evaluate community 150
# Botnet community 17
# MCR:  0.05 AVG_DD:  0.825441927961651 AVG_MCR:  0.017811144351312504
# Scores:  (0.8636363636363636, 0.9595959595959596, 0.9090909090909092, [[95, 15], [4, 65422]])
# Evaluate community 150
# Botnet community 5
# MCR:  0.05 AVG_DD:  0.8495847296276671 AVG_MCR:  0.08933575218811554
# Scores:  (0.8962264150943396, 0.9595959595959596, 0.926829268292683, [[95, 11], [4, 65426]])
# Evaluate community 150
# Botnet community 8
# MCR:  0.05 AVG_DD:  0.8324537886382487 AVG_MCR:  0.07049024161308655
# Scores:  (0.8962264150943396, 0.9595959595959596, 0.926829268292683, [[95, 11], [4, 65426]])
# Evaluate community 139
# Botnet community 4
# MCR:  0.017535935522786792 AVG_DD:  0.8422591638371286 AVG_MCR:  0.1
# Scores:  (0.9662921348314607, 0.8686868686868687, 0.9148936170212767, [[86, 3], [13, 65434]])
# Evaluate community 150
# Botnet community 7
# MCR:  0.05 AVG_DD:  0.8439176603002005 AVG_MCR:  0.07008456330702233
# Scores:  (0.8962264150943396, 0.9595959595959596, 0.926829268292683, [[95, 11], [4, 65426]])
# Evaluate community 150
# Botnet community 3
# MCR:  0.05 AVG_DD:  0.8661323378575844 AVG_MCR:  0.08117194343737184
# Scores:  (0.9215686274509803, 0.9494949494949495, 0.9353233830845771, [[94, 8], [5, 65429]])
# Evaluate community 150
# Botnet community 18
# MCR:  0.05 AVG_DD:  0.840342201112452 AVG_MCR:  0.001
# Scores:  (0.8636363636363636, 0.9595959595959596, 0.9090909090909092, [[95, 15], [4, 65422]])
# Evaluate community 150
# Botnet community 4
# MCR:  0.05 AVG_DD:  0.8592963696127196 AVG_MCR:  0.08275682080490424
# Scores:  (0.8952380952380953, 0.9494949494949495, 0.9215686274509803, [[94, 11], [5, 65426]])
# Evaluate community 150
# Botnet community 13
# MCR:  0.05 AVG_DD:  0.8709708548574814 AVG_MCR:  0.02578037596031097
# Scores:  (0.9550561797752809, 0.8585858585858586, 0.9042553191489363, [[85, 4], [14, 65433]])
# Evaluate community 150
# Botnet community 16
# MCR:  0.05 AVG_DD:  0.861826991865623 AVG_MCR:  0.01577479058537601
# Scores:  (0.8623853211009175, 0.9494949494949495, 0.9038461538461539, [[94, 15], [5, 65422]])
# Evaluate community 124
# Botnet community 7
# MCR:  0.001 AVG_DD:  0.93784974469937 AVG_MCR:  0.01910306632955315
# Scores:  (0.9540229885057471, 0.8383838383838383, 0.8924731182795698, [[83, 4], [16, 65433]])
# Evaluate community 150
# Botnet community 6
# MCR:  0.05 AVG_DD:  0.8040282329194453 AVG_MCR:  0.1
# Scores:  (0.8962264150943396, 0.9595959595959596, 0.926829268292683, [[95, 11], [4, 65426]])
# Evaluate community 124
# Botnet community 11
# MCR:  0.001 AVG_DD:  0.9160320866949628 AVG_MCR:  0.001
# Scores:  (0.9550561797752809, 0.8585858585858586, 0.9042553191489363, [[85, 4], [14, 65433]])
# Evaluate community 150
# Botnet community 9
# MCR:  0.05 AVG_DD:  0.9157946037978404 AVG_MCR:  0.029814399169028977
# Scores:  (0.9540229885057471, 0.8383838383838383, 0.8924731182795698, [[83, 4], [16, 65433]])
# Evaluate community 150
# Botnet community 2
# MCR:  0.05 AVG_DD:  0.8789233844308857 AVG_MCR:  0.07986637743355145
# Scores:  (1.0, 0.8383838383838383, 0.9120879120879121, [[83, 0], [16, 65437]])
# Evaluate community 124
# Botnet community 2
# MCR:  0.001 AVG_DD:  0.8918298951485267 AVG_MCR:  0.1
# Scores:  (1.0, 0.8383838383838383, 0.9120879120879121, [[83, 0], [16, 65437]])
# Evaluate community 150
# Botnet community 18
# MCR:  0.05 AVG_DD:  0.8515554530091228 AVG_MCR:  0.001
# Scores:  (0.8636363636363636, 0.9595959595959596, 0.9090909090909092, [[95, 15], [4, 65422]])
# Evaluate community 150
# Botnet community 10
# MCR:  0.05 AVG_DD:  0.9015831654081262 AVG_MCR:  0.03534482584328799
# Scores:  (0.9540229885057471, 0.8383838383838383, 0.8924731182795698, [[83, 4], [16, 65433]])
# Evaluate community 124
# Botnet community 2
# MCR:  0.001 AVG_DD:  0.965598140640312 AVG_MCR:  0.001
# Scores:  (1.0, 0.7676767676767676, 0.8685714285714284, [[76, 0], [23, 65437]])
# Evaluate community 150
# Botnet community 15
# MCR:  0.05 AVG_DD:  0.8041810721765432 AVG_MCR:  0.03857075922565825
# Scores:  (0.8636363636363636, 0.9595959595959596, 0.9090909090909092, [[95, 15], [4, 65422]])
# Evaluate community 150
# Botnet community 19
# MCR:  0.05 AVG_DD:  0.8154736708410036 AVG_MCR:  0.001
# Scores:  (0.8636363636363636, 0.9595959595959596, 0.9090909090909092, [[95, 15], [4, 65422]])
# Evaluate community 150
# Botnet community 15
# MCR:  0.05 AVG_DD:  0.8165887166416866 AVG_MCR:  0.038427637699091154
# Scores:  (0.8636363636363636, 0.9595959595959596, 0.9090909090909092, [[95, 15], [4, 65422]])
# Evaluate community 124
# Botnet community 12
# MCR:  0.001 AVG_DD:  0.8995926703767403 AVG_MCR:  0.001
# Scores:  (0.9550561797752809, 0.8585858585858586, 0.9042553191489363, [[85, 4], [14, 65433]])
# Evaluate community 150
# Botnet community 16
# MCR:  0.05 AVG_DD:  0.8461588392554079 AVG_MCR:  0.025700650931787816
# Scores:  (0.8636363636363636, 0.9595959595959596, 0.9090909090909092, [[95, 15], [4, 65422]])
# Evaluate community 150
# Botnet community 5
# MCR:  0.05 AVG_DD:  0.8372990662111053 AVG_MCR:  0.08984668903702532
# Scores:  (0.8962264150943396, 0.9595959595959596, 0.926829268292683, [[95, 11], [4, 65426]])
# Evaluate community 124
# Botnet community 13
# MCR:  0.001 AVG_DD:  0.8952118028853315 AVG_MCR:  0.01813292483370156
# Scores:  (0.9550561797752809, 0.8585858585858586, 0.9042553191489363, [[85, 4], [14, 65433]])
# Evaluate community 150
# Botnet community 4
# MCR:  0.05 AVG_DD:  0.9440634929431648 AVG_MCR:  0.03717453692415363
# Scores:  (0.9540229885057471, 0.8383838383838383, 0.8924731182795698, [[83, 4], [16, 65433]])
# Evaluate community 124
# Botnet community 2
# MCR:  0.001 AVG_DD:  0.9595376440018747 AVG_MCR:  0.001
# Scores:  (1.0, 0.7676767676767676, 0.8685714285714284, [[76, 0], [23, 65437]])
# Evaluate community 150
# Botnet community 6
# MCR:  0.05 AVG_DD:  0.8195082389927864 AVG_MCR:  0.1
# Scores:  (0.8962264150943396, 0.9595959595959596, 0.926829268292683, [[95, 11], [4, 65426]])
# Evaluate community 150
# Botnet community 7
# MCR:  0.05 AVG_DD:  0.8028798891349175 AVG_MCR:  0.07113990031114556
# Scores:  (0.8962264150943396, 0.9595959595959596, 0.926829268292683, [[95, 11], [4, 65426]])
# Evaluate community 150
# Botnet community 16
# MCR:  0.05 AVG_DD:  0.8289323149139138 AVG_MCR:  0.033532318266496074
# Scores:  (0.8636363636363636, 0.9595959595959596, 0.9090909090909092, [[95, 15], [4, 65422]])
# Evaluate community 150
# Botnet community 4
# MCR:  0.05 AVG_DD:  0.8577913680294642 AVG_MCR:  0.1
# Scores:  (0.8952380952380953, 0.9494949494949495, 0.9215686274509803, [[94, 11], [5, 65426]])
# Evaluate community 150
# Botnet community 7
# MCR:  0.05 AVG_DD:  0.852597121037284 AVG_MCR:  0.06906307847169846
# Scores:  (0.8962264150943396, 0.9595959595959596, 0.926829268292683, [[95, 11], [4, 65426]])
# Evaluate community 150
# Botnet community 7
# MCR:  0.05 AVG_DD:  0.8151181010495142 AVG_MCR:  0.07191190011942807
# Scores:  (0.8962264150943396, 0.9595959595959596, 0.926829268292683, [[95, 11], [4, 65426]])
# Evaluate community 124
# Botnet community 19
# MCR:  0.001 AVG_DD:  0.804410069312612 AVG_MCR:  0.001
# Scores:  (0.8558558558558559, 0.9595959595959596, 0.9047619047619048, [[95, 16], [4, 65421]])
# Evaluate community 150
# Botnet community 7
# MCR:  0.05 AVG_DD:  0.8076942460490404 AVG_MCR:  0.07081409764637578
# Scores:  (0.8962264150943396, 0.9595959595959596, 0.926829268292683, [[95, 11], [4, 65426]])
# Evaluate community 150
# Botnet community 9
# MCR:  0.05 AVG_DD:  0.8284110490206084 AVG_MCR:  0.06545341052135058
# Scores:  (0.8962264150943396, 0.9595959595959596, 0.926829268292683, [[95, 11], [4, 65426]])
# Evaluate community 150
# Botnet community 5
# MCR:  0.05 AVG_DD:  0.9459638238107794 AVG_MCR:  0.001
# Scores:  (0.9534883720930233, 0.8282828282828283, 0.8864864864864866, [[82, 4], [17, 65433]])
# Evaluate community 150
# Botnet community 1
# MCR:  0.05 AVG_DD:  0.9732795624172925 AVG_MCR:  0.001
# Scores:  (1.0, 0.5959595959595959, 0.7468354430379746, [[59, 0], [40, 65437]])
# Evaluate community 150
# Botnet community 9
# MCR:  0.05 AVG_DD:  0.8608052634136092 AVG_MCR:  0.05508023758287711
# Scores:  (0.8623853211009175, 0.9494949494949495, 0.9038461538461539, [[94, 15], [5, 65422]])
# Evaluate community 150
# Botnet community 8
# MCR:  0.05 AVG_DD:  0.8735275461060689 AVG_MCR:  0.04462252096224591
# Scores:  (0.9540229885057471, 0.8383838383838383, 0.8924731182795698, [[83, 4], [16, 65433]])
# Evaluate community 124
# Botnet community 2
# MCR:  0.001 AVG_DD:  0.9657272012429661 AVG_MCR:  0.024587018627667847
# Scores:  (1.0, 0.7676767676767676, 0.8685714285714284, [[76, 0], [23, 65437]])
# Evaluate community 150
# Botnet community 8
# MCR:  0.05 AVG_DD:  0.8475946406914502 AVG_MCR:  0.0636874991116825
# Scores:  (0.8962264150943396, 0.9595959595959596, 0.926829268292683, [[95, 11], [4, 65426]])
# Evaluate community 150
# Botnet community 18
# MCR:  0.05 AVG_DD:  0.8387171525246393 AVG_MCR:  0.012188454415048348
# Scores:  (0.8636363636363636, 0.9595959595959596, 0.9090909090909092, [[95, 15], [4, 65422]])
# Evaluate community 150
# Botnet community 5
# MCR:  0.05 AVG_DD:  0.8572987308953156 AVG_MCR:  0.07159016272090508
# Scores:  (0.8952380952380953, 0.9494949494949495, 0.9215686274509803, [[94, 11], [5, 65426]])
# Evaluate community 150
# Botnet community 10
# MCR:  0.05 AVG_DD:  0.854769563599057 AVG_MCR:  0.04914615711004629
# Scores:  (0.8636363636363636, 0.9595959595959596, 0.9090909090909092, [[95, 15], [4, 65422]])
# Evaluate community 150
# Botnet community 14
# MCR:  0.05 AVG_DD:  0.8650750956195373 AVG_MCR:  0.02956451329759528
# Scores:  (0.8867924528301887, 0.9494949494949495, 0.9170731707317074, [[94, 12], [5, 65425]])
# Evaluate community 150
# Botnet community 15
# MCR:  0.05 AVG_DD:  0.8788233431470407 AVG_MCR:  0.001
# Scores:  (0.9550561797752809, 0.8585858585858586, 0.9042553191489363, [[85, 4], [14, 65433]])
# Evaluate community 124
# Botnet community 7
# MCR:  0.001 AVG_DD:  0.9380968809182253 AVG_MCR:  0.035871274350294385
# Scores:  (0.9540229885057471, 0.8383838383838383, 0.8924731182795698, [[83, 4], [16, 65433]])
# Evaluate community 150
# Botnet community 6
# MCR:  0.05 AVG_DD:  0.8309040448199481 AVG_MCR:  0.1
# Scores:  (0.8962264150943396, 0.9595959595959596, 0.926829268292683, [[95, 11], [4, 65426]])
# Evaluate community 150
# Botnet community 16
# MCR:  0.05 AVG_DD:  0.83490110484343 AVG_MCR:  0.03626395697031025
# Scores:  (0.8636363636363636, 0.9595959595959596, 0.9090909090909092, [[95, 15], [4, 65422]])
# Evaluate community 150
# Botnet community 5
# MCR:  0.05 AVG_DD:  0.845968448762771 AVG_MCR:  0.08355904114627469
# Scores:  (0.8962264150943396, 0.9595959595959596, 0.926829268292683, [[95, 11], [4, 65426]])
# Evaluate community 150
# Botnet community 18
# MCR:  0.05 AVG_DD:  0.8199001662006973 AVG_MCR:  0.016274268115805055
# Scores:  (0.8636363636363636, 0.9595959595959596, 0.9090909090909092, [[95, 15], [4, 65422]])
# Evaluate community 124
# Botnet community 11
# MCR:  0.001 AVG_DD:  0.8894792658485347 AVG_MCR:  0.034229336644934445
# Scores:  (0.9540229885057471, 0.8383838383838383, 0.8924731182795698, [[83, 4], [16, 65433]])
# Evaluate community 150
# Botnet community 2
# MCR:  0.04913825149080353 AVG_DD:  0.8781166886081881 AVG_MCR:  0.09817623473271776
# Scores:  (1.0, 0.8383838383838383, 0.9120879120879121, [[83, 0], [16, 65437]])
# Evaluate community 150
# Botnet community 6
# MCR:  0.05 AVG_DD:  0.9422067364667274 AVG_MCR:  0.025554013004072423
# Scores:  (0.9540229885057471, 0.8383838383838383, 0.8924731182795698, [[83, 4], [16, 65433]])
# Evaluate community 150
# Botnet community 4
# MCR:  0.05 AVG_DD:  0.8637095651397363 AVG_MCR:  0.08135064306367518
# Scores:  (0.8952380952380953, 0.9494949494949495, 0.9215686274509803, [[94, 11], [5, 65426]])
# Evaluate community 150
# Botnet community 5
# MCR:  0.05 AVG_DD:  0.8548260433389709 AVG_MCR:  0.09066155223276658
# Scores:  (0.8962264150943396, 0.9595959595959596, 0.926829268292683, [[95, 11], [4, 65426]])
# Evaluate community 150
# Botnet community 17
# MCR:  0.05 AVG_DD:  0.8109234329845346 AVG_MCR:  0.02327417772417176
# Scores:  (0.8636363636363636, 0.9595959595959596, 0.9090909090909092, [[95, 15], [4, 65422]])
# Evaluate community 148
# Botnet community 7
# MCR:  0.043924461685353994 AVG_DD:  0.940559281894054 AVG_MCR:  0.001
# Scores:  (0.9540229885057471, 0.8383838383838383, 0.8924731182795698, [[83, 4], [16, 65433]])
# Evaluate community 150
# Botnet community 16
# MCR:  0.05 AVG_DD:  0.8502985542678915 AVG_MCR:  0.01770779971152968
# Scores:  (0.8636363636363636, 0.9595959595959596, 0.9090909090909092, [[95, 15], [4, 65422]])
# Evaluate community 124
# Botnet community 5
# MCR:  0.001 AVG_DD:  0.882828063901371 AVG_MCR:  0.07206086692596629
# Scores:  (1.0, 0.8383838383838383, 0.9120879120879121, [[83, 0], [16, 65437]])
# Evaluate community 124
# Botnet community 10
# MCR:  0.001 AVG_DD:  0.9110121966843377 AVG_MCR:  0.03534339990639987
# Scores:  (0.9540229885057471, 0.8383838383838383, 0.8924731182795698, [[83, 4], [16, 65433]])
# Evaluate community 124
# Botnet community 4
# MCR:  0.001 AVG_DD:  0.8021444290186157 AVG_MCR:  0.09263629635868077
# Scores:  (0.9666666666666667, 0.8787878787878788, 0.9206349206349207, [[87, 3], [12, 65434]])
# Evaluate community 124
# Botnet community 4
# MCR:  0.001 AVG_DD:  0.8190631181141571 AVG_MCR:  0.09164104782467204
# Scores:  (0.9666666666666667, 0.8787878787878788, 0.9206349206349207, [[87, 3], [12, 65434]])
# Evaluate community 150
# Botnet community 15
# MCR:  0.05 AVG_DD:  0.8697607216424939 AVG_MCR:  0.006875230899956913
# Scores:  (0.9550561797752809, 0.8585858585858586, 0.9042553191489363, [[85, 4], [14, 65433]])
# Evaluate community 124
# Botnet community 0
# MCR:  0.001 AVG_DD:  1.0 AVG_MCR:  0.1
# Scores:  (0, 0.0, 0, [[0, 0], [99, 65437]])
# Evaluate community 124
# Botnet community 14
# MCR:  0.001 AVG_DD:  0.8807698698373297 AVG_MCR:  0.012367611261999645
# Scores:  (0.9550561797752809, 0.8585858585858586, 0.9042553191489363, [[85, 4], [14, 65433]])
# Evaluate community 150
# Botnet community 11
# MCR:  0.05 AVG_DD:  0.8083361273278464 AVG_MCR:  0.05713913203013513
# Scores:  (0.8636363636363636, 0.9595959595959596, 0.9090909090909092, [[95, 15], [4, 65422]])
# Evaluate community 150
# Botnet community 6
# MCR:  0.05 AVG_DD:  0.8088078153989657 AVG_MCR:  0.0824432289815158
# Scores:  (0.8962264150943396, 0.9595959595959596, 0.926829268292683, [[95, 11], [4, 65426]])
# Evaluate community 124
# Botnet community 1
# MCR:  0.001 AVG_DD:  0.9466880725551057 AVG_MCR:  0.056629886608191723
# Scores:  (0.0, 0.0, 0, [[0, 4], [99, 65433]])
# Evaluate community 124
# Botnet community 4
# MCR:  0.001 AVG_DD:  0.9513203235934246 AVG_MCR:  0.029174115340118965
# Scores:  (0.9534883720930233, 0.8282828282828283, 0.8864864864864866, [[82, 4], [17, 65433]])
# Evaluate community 150
# Botnet community 2
# MCR:  0.05 AVG_DD:  0.9600808902045856 AVG_MCR:  0.03056535695432572
# Scores:  (1.0, 0.7676767676767676, 0.8685714285714284, [[76, 0], [23, 65437]])
# Evaluate community 124
# Botnet community 12
# MCR:  0.001 AVG_DD:  0.9013674516071898 AVG_MCR:  0.012265104535767436
# Scores:  (0.9550561797752809, 0.8585858585858586, 0.9042553191489363, [[85, 4], [14, 65433]])
# Evaluate community 124
# Botnet community 16
# MCR:  0.001 AVG_DD:  0.8555624670865403 AVG_MCR:  0.027151094329132153
# Scores:  (0.8545454545454545, 0.9494949494949495, 0.8995215311004785, [[94, 16], [5, 65421]])
# Evaluate community 150
# Botnet community 10
# MCR:  0.05 AVG_DD:  0.8 AVG_MCR:  0.0607785230911786
# Scores:  (0.8878504672897196, 0.9595959595959596, 0.9223300970873787, [[95, 12], [4, 65425]])
# Evaluate community 150
# Botnet community 14
# MCR:  0.05 AVG_DD:  0.8420300347206655 AVG_MCR:  0.03806056821357267
# Scores:  (0.8636363636363636, 0.9595959595959596, 0.9090909090909092, [[95, 15], [4, 65422]])
# Evaluate community 124
# Botnet community 17
# MCR:  0.001 AVG_DD:  0.8171086874357233 AVG_MCR:  0.027204252992749263
# Scores:  (0.8558558558558559, 0.9595959595959596, 0.9047619047619048, [[95, 16], [4, 65421]])
# Evaluate community 150
# Botnet community 6
# MCR:  0.05 AVG_DD:  0.8266732693693407 AVG_MCR:  0.08838340876873292
# Scores:  (0.8962264150943396, 0.9595959595959596, 0.926829268292683, [[95, 11], [4, 65426]])
# Evaluate community 124
# Botnet community 8
# MCR:  0.001 AVG_DD:  0.930877079142695 AVG_MCR:  0.012625486680269232
# Scores:  (0.9540229885057471, 0.8383838383838383, 0.8924731182795698, [[83, 4], [16, 65433]])
# Evaluate community 150
# Botnet community 9
# MCR:  0.05 AVG_DD:  0.8345891578452354 AVG_MCR:  0.06319495050053668
# Scores:  (0.8962264150943396, 0.9595959595959596, 0.926829268292683, [[95, 11], [4, 65426]])
# Evaluate community 131
# Botnet community 1
# MCR:  0.008839749120285834 AVG_DD:  0.9694959877516728 AVG_MCR:  0.04166667586144288
# Scores:  (1.0, 0.5959595959595959, 0.7468354430379746, [[59, 0], [40, 65437]])
# Evaluate community 150
# Botnet community 17
# MCR:  0.05 AVG_DD:  0.8054005102707658 AVG_MCR:  0.028469111440161905
# Scores:  (0.8636363636363636, 0.9595959595959596, 0.9090909090909092, [[95, 15], [4, 65422]])
# Evaluate community 124
# Botnet community 10
# MCR:  0.001 AVG_DD:  0.9178495399824796 AVG_MCR:  0.012309774119022395
# Scores:  (0.9540229885057471, 0.8383838383838383, 0.8924731182795698, [[83, 4], [16, 65433]])
# Evaluate community 124
# Botnet community 5
# MCR:  0.001 AVG_DD:  0.9453753837845827 AVG_MCR:  0.03158173026761722
# Scores:  (0.9534883720930233, 0.8282828282828283, 0.8864864864864866, [[82, 4], [17, 65433]])
# Evaluate community 124
# Botnet community 2
# MCR:  0.001 AVG_DD:  0.8816104450955476 AVG_MCR:  0.0923856582332404
# Scores:  (1.0, 0.8383838383838383, 0.9120879120879121, [[83, 0], [16, 65437]])
# Evaluate community 150
# Botnet community 8
# MCR:  0.05 AVG_DD:  0.8395498322850103 AVG_MCR:  0.06589744746854978
# Scores:  (0.8962264150943396, 0.9595959595959596, 0.926829268292683, [[95, 11], [4, 65426]])
# Evaluate community 150
# Botnet community 19
# MCR:  0.05 AVG_DD:  0.8301562272333581 AVG_MCR:  0.009235628458315683
# Scores:  (0.8636363636363636, 0.9595959595959596, 0.9090909090909092, [[95, 15], [4, 65422]])
# Evaluate community 150
# Botnet community 11
# MCR:  0.05 AVG_DD:  0.8182866501231199 AVG_MCR:  0.050456216838447185
# Scores:  (0.8636363636363636, 0.9595959595959596, 0.9090909090909092, [[95, 15], [4, 65422]])
# Evaluate community 150
# Botnet community 9
# MCR:  0.05 AVG_DD:  0.8217576808265692 AVG_MCR:  0.06384358606743336
# Scores:  (0.8962264150943396, 0.9595959595959596, 0.926829268292683, [[95, 11], [4, 65426]])
# Evaluate community 150
# Botnet community 5
# MCR:  0.05 AVG_DD:  0.8451652864920933 AVG_MCR:  0.0926164491688033
# Scores:  (0.8962264150943396, 0.9595959595959596, 0.926829268292683, [[95, 11], [4, 65426]])
# Evaluate community 150
# Botnet community 6
# MCR:  0.05 AVG_DD:  0.8061525854985259 AVG_MCR:  0.09010210564846738
# Scores:  (0.8962264150943396, 0.9595959595959596, 0.926829268292683, [[95, 11], [4, 65426]])
# Evaluate community 124
# Botnet community 10
# MCR:  0.001 AVG_DD:  0.890131076243772 AVG_MCR:  0.04764120575554242
# Scores:  (0.9540229885057471, 0.8383838383838383, 0.8924731182795698, [[83, 4], [16, 65433]])
# Evaluate community 150
# Botnet community 8
# MCR:  0.05 AVG_DD:  0.8688697645471508 AVG_MCR:  0.05843788979432132
# Scores:  (0.8867924528301887, 0.9494949494949495, 0.9170731707317074, [[94, 12], [5, 65425]])
# Evaluate community 124
# Botnet community 14
# MCR:  0.001 AVG_DD:  0.874692526139988 AVG_MCR:  0.014485977369890234
# Scores:  (0.9550561797752809, 0.8585858585858586, 0.9042553191489363, [[85, 4], [14, 65433]])
# Evaluate community 150
# Botnet community 6
# MCR:  0.05 AVG_DD:  0.8229053141570838 AVG_MCR:  0.09358263212481865
# Scores:  (0.8962264150943396, 0.9595959595959596, 0.926829268292683, [[95, 11], [4, 65426]])
# Evaluate community 124
# Botnet community 11
# MCR:  0.001 AVG_DD:  0.8031769699523026 AVG_MCR:  0.05488305132240686
# Scores:  (0.8558558558558559, 0.9595959595959596, 0.9047619047619048, [[95, 16], [4, 65421]])
# Evaluate community 150
# Botnet community 19
# MCR:  0.05 AVG_DD:  0.8097633007703786 AVG_MCR:  0.00967418471043853
# Scores:  (0.8636363636363636, 0.9595959595959596, 0.9090909090909092, [[95, 15], [4, 65422]])
# Evaluate community 150
# Botnet community 6
# MCR:  0.05 AVG_DD:  0.8148346004127947 AVG_MCR:  0.0915245706858476
# Scores:  (0.8962264150943396, 0.9595959595959596, 0.926829268292683, [[95, 11], [4, 65426]])
# Evaluate community 150
# Botnet community 8
# MCR:  0.05 AVG_DD:  0.9189890931698756 AVG_MCR:  0.03763244672381125
# Scores:  (0.9540229885057471, 0.8383838383838383, 0.8924731182795698, [[83, 4], [16, 65433]])
# Evaluate community 124
# Botnet community 8
# MCR:  0.001 AVG_DD:  0.8729238958656472 AVG_MCR:  0.058135024021420026
# Scores:  (0.8545454545454545, 0.9494949494949495, 0.8995215311004785, [[94, 16], [5, 65421]])
# Evaluate community 150
# Botnet community 17
# MCR:  0.05 AVG_DD:  0.8 AVG_MCR:  0.036108894644486786
# Scores:  (0.8558558558558559, 0.9595959595959596, 0.9047619047619048, [[95, 16], [4, 65421]])
# Evaluate community 124
# Botnet community 7
# MCR:  0.001 AVG_DD:  0.8652125321587516 AVG_MCR:  0.06274428162518374
# Scores:  (0.8545454545454545, 0.9494949494949495, 0.8995215311004785, [[94, 16], [5, 65421]])
# Evaluate community 124
# Botnet community 15
# MCR:  0.001 AVG_DD:  0.8640123218712721 AVG_MCR:  0.006083712191561658
# Scores:  (0.8545454545454545, 0.9494949494949495, 0.8995215311004785, [[94, 16], [5, 65421]])
# Evaluate community 150
# Botnet community 7
# MCR:  0.05 AVG_DD:  0.9368838134180107 AVG_MCR:  0.028769268804793635
# Scores:  (0.9540229885057471, 0.8383838383838383, 0.8924731182795698, [[83, 4], [16, 65433]])
# Evaluate community 150
# Botnet community 6
# MCR:  0.05 AVG_DD:  0.9423809887250678 AVG_MCR:  0.010292748660276605
# Scores:  (0.9540229885057471, 0.8383838383838383, 0.8924731182795698, [[83, 4], [16, 65433]])
# Evaluate community 150
# Botnet community 9
# MCR:  0.05 AVG_DD:  0.812246082584056 AVG_MCR:  0.06580700069948141
# Scores:  (0.8962264150943396, 0.9595959595959596, 0.926829268292683, [[95, 11], [4, 65426]])
# Evaluate community 150
# Botnet community 6
# MCR:  0.05 AVG_DD:  0.8332643042988026 AVG_MCR:  0.09421128400890384
# Scores:  (0.8962264150943396, 0.9595959595959596, 0.926829268292683, [[95, 11], [4, 65426]])
# Evaluate community 150
# Botnet community 12
# MCR:  0.05 AVG_DD:  0.8265177820745426 AVG_MCR:  0.043742606527043815
# Scores:  (0.8636363636363636, 0.9595959595959596, 0.9090909090909092, [[95, 15], [4, 65422]])
# Evaluate community 150
# Botnet community 8
# MCR:  0.05 AVG_DD:  0.8438422700926251 AVG_MCR:  0.060219319161082245
# Scores:  (0.8962264150943396, 0.9595959595959596, 0.926829268292683, [[95, 11], [4, 65426]])
# Evaluate community 150
# Botnet community 2
# MCR:  0.05 AVG_DD:  0.9680996285470701 AVG_MCR:  0.013167592389810301
# Scores:  (1.0, 0.7676767676767676, 0.8685714285714284, [[76, 0], [23, 65437]])
# Evaluate community 144
# Botnet community 0
# MCR:  0.023092224836455854 AVG_DD:  0.9798465791374603 AVG_MCR:  0.1
# Scores:  (0, 0.0, 0, [[0, 0], [99, 65437]])
# Evaluate community 124
# Botnet community 12
# MCR:  0.001 AVG_DD:  0.9082412356419348 AVG_MCR:  0.017677308707313006
# Scores:  (0.9550561797752809, 0.8585858585858586, 0.9042553191489363, [[85, 4], [14, 65433]])
# Evaluate community 124
# Botnet community 18
# MCR:  0.001 AVG_DD:  0.8 AVG_MCR:  0.009354562806289803
# Scores:  (0.8558558558558559, 0.9595959595959596, 0.9047619047619048, [[95, 16], [4, 65421]])
# Evaluate community 150
# Botnet community 19
# MCR:  0.05 AVG_DD:  0.8240380196772773 AVG_MCR:  0.008240941267421885
# Scores:  (0.8636363636363636, 0.9595959595959596, 0.9090909090909092, [[95, 15], [4, 65422]])
# Evaluate community 150
# Botnet community 4
# MCR:  0.05 AVG_DD:  0.9511761643910384 AVG_MCR:  0.0112810613346447
# Scores:  (0.9534883720930233, 0.8282828282828283, 0.8864864864864866, [[82, 4], [17, 65433]])
# Evaluate community 150
# Botnet community 4
# MCR:  0.05 AVG_DD:  0.8889077207288166 AVG_MCR:  0.07051239155785838
# Scores:  (1.0, 0.8383838383838383, 0.9120879120879121, [[83, 0], [16, 65437]])
# Evaluate community 150
# Botnet community 15
# MCR:  0.05 AVG_DD:  0.8611945998800337 AVG_MCR:  0.02690396573003657
# Scores:  (0.8623853211009175, 0.9494949494949495, 0.9038461538461539, [[94, 15], [5, 65422]])
# Evaluate community 150
# Botnet community 8
# MCR:  0.05 AVG_DD:  0.8845471113142868 AVG_MCR:  0.04713675712585743
# Scores:  (0.9540229885057471, 0.8383838383838383, 0.8924731182795698, [[83, 4], [16, 65433]])
# Evaluate community 150
# Botnet community 5
# MCR:  0.05 AVG_DD:  0.8413025907914101 AVG_MCR:  0.07709915775040413
# Scores:  (0.8962264150943396, 0.9595959595959596, 0.926829268292683, [[95, 11], [4, 65426]])
# Evaluate community 150
# Botnet community 17
# MCR:  0.05 AVG_DD:  0.843710430987415 AVG_MCR:  0.01626095498784425
# Scores:  (0.8636363636363636, 0.9595959595959596, 0.9090909090909092, [[95, 15], [4, 65422]])
# Evaluate community 124
# Botnet community 13
# MCR:  0.001 AVG_DD:  0.8958109177088811 AVG_MCR:  0.008310059905274687
# Scores:  (0.9550561797752809, 0.8585858585858586, 0.9042553191489363, [[85, 4], [14, 65433]])
# Evaluate community 150
# Botnet community 5
# MCR:  0.05 AVG_DD:  0.850831665266428 AVG_MCR:  0.082021210141396
# Scores:  (0.8962264150943396, 0.9595959595959596, 0.926829268292683, [[95, 11], [4, 65426]])
# Evaluate community 150
# Botnet community 1
# MCR:  0.05 AVG_DD:  0.9732628504573059 AVG_MCR:  0.02582900908072244
# Scores:  (1.0, 0.5959595959595959, 0.7468354430379746, [[59, 0], [40, 65437]])
# Evaluate community 124
# Botnet community 13
# MCR:  0.001 AVG_DD:  0.8890071930988453 AVG_MCR:  0.001
# Scores:  (0.9550561797752809, 0.8585858585858586, 0.9042553191489363, [[85, 4], [14, 65433]])
# Evaluate community 150
# Botnet community 4
# MCR:  0.05 AVG_DD:  0.8593850764333121 AVG_MCR:  0.09208740850130155
# Scores:  (0.8952380952380953, 0.9494949494949495, 0.9215686274509803, [[94, 11], [5, 65426]])
# Evaluate community 150
# Botnet community 10
# MCR:  0.05 AVG_DD:  0.8495411177299254 AVG_MCR:  0.05108414332328425
# Scores:  (0.8636363636363636, 0.9595959595959596, 0.9090909090909092, [[95, 15], [4, 65422]])
# Evaluate community 150
# Botnet community 6
# MCR:  0.05 AVG_DD:  0.8312616459645134 AVG_MCR:  0.07867924247815447
# ...
# Evaluate community 125
# Botnet community 13
# MCR:  0.0011727318526575468 AVG_DD:  0.8826053619623483 AVG_MCR:  0.019079364576252436
# Scores:  (0.9550561797752809, 0.8585858585858586, 0.9042553191489363, [[85, 4], [14, 65433]])
# Evaluate community 150
# Botnet community 5
# MCR:  0.04950521210122904 AVG_DD:  0.864475506784959 AVG_MCR:  0.0699299488086789
# Scores:  (0.9215686274509803, 0.9494949494949495, 0.9353233830845771, [[94, 8], [5, 65429]])
# Evaluate community 148
# Botnet community 7
# MCR:  0.0462959879521093 AVG_DD:  0.9335702761148622 AVG_MCR:  0.01951247863080408
# Scores:  (0.9540229885057471, 0.8383838383838383, 0.8924731182795698, [[83, 4], [16, 65433]])
# Evaluate community 150
# Botnet community 3
# MCR:  0.04951295941377081 AVG_DD:  0.8662235990652553 AVG_MCR:  0.07852498001011418
# Scores:  (0.9215686274509803, 0.9494949494949495, 0.9353233830845771, [[94, 8], [5, 65429]])
# Evaluate community 148
# Botnet community 14
# MCR:  0.04834894037049829 AVG_DD:  0.838596450896029 AVG_MCR:  0.03661364498258903
# Scores:  (0.8636363636363636, 0.9595959595959596, 0.9090909090909092, [[95, 15], [4, 65422]])
# Evaluate community 125
# Botnet community 15
# MCR:  0.0015886990789261252 AVG_DD:  0.8241068398297218 AVG_MCR:  0.03856370776680187
# Scores:  (0.8558558558558559, 0.9595959595959596, 0.9047619047619048, [[95, 16], [4, 65421]])
# Evaluate community 150
# Botnet community 3
# MCR:  0.04989270374969626 AVG_DD:  0.8663059937685773 AVG_MCR:  0.08533870338016672
# Scores:  (0.9215686274509803, 0.9494949494949495, 0.9353233830845771, [[94, 8], [5, 65429]])
# Evaluate community 126
# Botnet community 7
# MCR:  0.002744813437571112 AVG_DD:  0.8817654674588179 AVG_MCR:  0.05871439265084786
# Scores:  (0.9540229885057471, 0.8383838383838383, 0.8924731182795698, [[83, 4], [16, 65433]])
# Evaluate community 125
# Botnet community 17
# MCR:  0.001556023439213292 AVG_DD:  0.802085464091779 AVG_MCR:  0.029532242110589597
# Scores:  (0.8558558558558559, 0.9595959595959596, 0.9047619047619048, [[95, 16], [4, 65421]])
# Evaluate community 148
# Botnet community 9
# MCR:  0.04865917818488615 AVG_DD:  0.8628373196195267 AVG_MCR:  0.04686936299319425
# Scores:  (0.8623853211009175, 0.9494949494949495, 0.9038461538461539, [[94, 15], [5, 65422]])
# Evaluate community 126
# Botnet community 17
# MCR:  0.003187150898638382 AVG_DD:  0.808411788797708 AVG_MCR:  0.02912864544792275
# Scores:  (0.8558558558558559, 0.9595959595959596, 0.9047619047619048, [[95, 16], [4, 65421]])
# Evaluate community 130
# Botnet community 18
# MCR:  0.005449227285204489 AVG_DD:  0.8274694153678186 AVG_MCR:  0.007644029577604379
# Scores:  (0.8558558558558559, 0.9595959595959596, 0.9047619047619048, [[95, 16], [4, 65421]])
# Evaluate community 147
# Botnet community 7
# MCR:  0.04261089658560603 AVG_DD:  0.9111770769605874 AVG_MCR:  0.04592004602811172
# Scores:  (0.9540229885057471, 0.8383838383838383, 0.8924731182795698, [[83, 4], [16, 65433]])
# Evaluate community 150
# Botnet community 4
# MCR:  0.04954716148444979 AVG_DD:  0.8567381845770548 AVG_MCR:  0.07970474423022954
# Scores:  (0.8952380952380953, 0.9494949494949495, 0.9215686274509803, [[94, 11], [5, 65426]])
# Evaluate community 148
# Botnet community 3
# MCR:  0.04834589748538879 AVG_DD:  0.8688397274576191 AVG_MCR:  0.09494657041517428
# Scores:  (0.9215686274509803, 0.9494949494949495, 0.9353233830845771, [[94, 8], [5, 65429]])
# Evaluate community 149
# Botnet community 6
# MCR:  0.04879340921246066 AVG_DD:  0.8212194873551928 AVG_MCR:  0.09530899075081577
# Scores:  (0.8962264150943396, 0.9595959595959596, 0.926829268292683, [[95, 11], [4, 65426]])
# Evaluate community 148
# Botnet community 2
# MCR:  0.048575005300996114 AVG_DD:  0.8731020722748231 AVG_MCR:  0.09346097903356819
# Scores:  (1.0, 0.8383838383838383, 0.9120879120879121, [[83, 0], [16, 65437]])
# Evaluate community 148
# Botnet community 7
# MCR:  0.04804110694095802 AVG_DD:  0.8791932430031334 AVG_MCR:  0.0464912528366441
# Scores:  (0.9540229885057471, 0.8383838383838383, 0.8924731182795698, [[83, 4], [16, 65433]])
# Evaluate community 148
# Botnet community 5
# MCR:  0.0480081509426842 AVG_DD:  0.840128000057581 AVG_MCR:  0.0865765763389408
# Scores:  (0.8962264150943396, 0.9595959595959596, 0.926829268292683, [[95, 11], [4, 65426]])
# Evaluate community 150
# Botnet community 6
# MCR:  0.0499293816651677 AVG_DD:  0.8662665156047485 AVG_MCR:  0.06613961439585622
# Scores:  (0.9215686274509803, 0.9494949494949495, 0.9353233830845771, [[94, 8], [5, 65429]])
# Evaluate community 148
# Botnet community 6
# MCR:  0.04739967924341298 AVG_DD:  0.8163248514504313 AVG_MCR:  0.07563141886591888
# Scores:  (0.8962264150943396, 0.9595959595959596, 0.926829268292683, [[95, 11], [4, 65426]])
# Evaluate community 148
# Botnet community 11
# MCR:  0.0468010612092265 AVG_DD:  0.898162981267459 AVG_MCR:  0.020193377278329646
# Scores:  (0.9540229885057471, 0.8383838383838383, 0.8924731182795698, [[83, 4], [16, 65433]])
# Evaluate community 150
# Botnet community 3
# MCR:  0.049954287079007224 AVG_DD:  0.866073946079619 AVG_MCR:  0.09694407893003947
# Scores:  (0.9215686274509803, 0.9494949494949495, 0.9353233830845771, [[94, 8], [5, 65429]])
# Evaluate community 148
# Botnet community 2
# MCR:  0.0473539601482668 AVG_DD:  0.8839193217368414 AVG_MCR:  0.09531955753754963
# Scores:  (1.0, 0.8383838383838383, 0.9120879120879121, [[83, 0], [16, 65437]])
# Evaluate community 130
# Botnet community 0
# MCR:  0.006428618485642638 AVG_DD:  0.9833907178841388 AVG_MCR:  0.0013933399617101216
# Scores:  (0, 0.0, 0, [[0, 0], [99, 65437]])
# Evaluate community 148
# Botnet community 4
# MCR:  0.048331011509739355 AVG_DD:  0.9157944892284143 AVG_MCR:  0.05160750291106105
# Scores:  (0.9540229885057471, 0.8383838383838383, 0.8924731182795698, [[83, 4], [16, 65433]])
# Evaluate community 148
# Botnet community 3
# MCR:  0.04695578737962955 AVG_DD:  0.8849772870879279 AVG_MCR:  0.07332587690988217
# Scores:  (1.0, 0.8383838383838383, 0.9120879120879121, [[83, 0], [16, 65437]])
# Evaluate community 126
# Botnet community 12
# MCR:  0.002136424124533265 AVG_DD:  0.9041695386383062 AVG_MCR:  0.0016690610008114806
# Scores:  (0.9550561797752809, 0.8585858585858586, 0.9042553191489363, [[85, 4], [14, 65433]])
# Evaluate community 129
# Botnet community 0
# MCR:  0.004961055287122558 AVG_DD:  0.9669210231446455 AVG_MCR:  0.0672556380993529
# Scores:  (0, 0.0, 0, [[0, 0], [99, 65437]])
# Evaluate community 126
# Botnet community 3
# MCR:  0.0019870963793563773 AVG_DD:  0.9550237144477024 AVG_MCR:  0.00761715134542941
# Scores:  (0.95, 0.7676767676767676, 0.8491620111731844, [[76, 4], [23, 65433]])
# Evaluate community 148
# Botnet community 2
# MCR:  0.04643945466839891 AVG_DD:  0.966262566937825 AVG_MCR:  0.03303612175229279
# Scores:  (1.0, 0.5959595959595959, 0.7468354430379746, [[59, 0], [40, 65437]])
# Evaluate community 124
# Botnet community 2
# MCR:  0.001 AVG_DD:  0.9613726531022176 AVG_MCR:  0.02102407299606776
# Scores:  (1.0, 0.7676767676767676, 0.8685714285714284, [[76, 0], [23, 65437]])
# Evaluate community 150
# Botnet community 2
# MCR:  0.05 AVG_DD:  0.8915476264544216 AVG_MCR:  0.0771293962476245
# Scores:  (1.0, 0.8383838383838383, 0.9120879120879121, [[83, 0], [16, 65437]])
# Evaluate community 125
# Botnet community 12
# MCR:  0.0016592723758941462 AVG_DD:  0.9099106378678381 AVG_MCR:  0.025810998487193974
# Scores:  (0.9550561797752809, 0.8585858585858586, 0.9042553191489363, [[85, 4], [14, 65433]])
# Evaluate community 130
# Botnet community 7
# MCR:  0.0076133350187332395 AVG_DD:  0.932487116680708 AVG_MCR:  0.044839759367220976
# Scores:  (0.9540229885057471, 0.8383838383838383, 0.8924731182795698, [[83, 4], [16, 65433]])
# Evaluate community 150
# Botnet community 6
# MCR:  0.049390561668748764 AVG_DD:  0.9032303846223532 AVG_MCR:  0.049329653631486454
# Scores:  (0.9540229885057471, 0.8383838383838383, 0.8924731182795698, [[83, 4], [16, 65433]])
# Evaluate community 150
# Botnet community 11
# MCR:  0.05 AVG_DD:  0.8484614920177496 AVG_MCR:  0.04388706059603012
# Scores:  (0.8636363636363636, 0.9595959595959596, 0.9090909090909092, [[95, 15], [4, 65422]])
# Evaluate community 148
# Botnet community 12
# MCR:  0.04569132692719107 AVG_DD:  0.8539272164506704 AVG_MCR:  0.04266038478324638
# Scores:  (0.8636363636363636, 0.9595959595959596, 0.9090909090909092, [[95, 15], [4, 65422]])
# Evaluate community 130
# Botnet community 7
# MCR:  0.007669354984563167 AVG_DD:  0.8978962060859292 AVG_MCR:  0.05537451940458348
# Scores:  (0.9540229885057471, 0.8383838383838383, 0.8924731182795698, [[83, 4], [16, 65433]])
# Evaluate community 148
# Botnet community 16
# MCR:  0.04775179092695864 AVG_DD:  0.8164225015377431 AVG_MCR:  0.02293235309131842
# Scores:  (0.8636363636363636, 0.9595959595959596, 0.9090909090909092, [[95, 15], [4, 65422]])
# Evaluate community 130
# Botnet community 2
# MCR:  0.006427068166968009 AVG_DD:  0.8804234345698408 AVG_MCR:  0.08528067641638344
# Scores:  (1.0, 0.8383838383838383, 0.9120879120879121, [[83, 0], [16, 65437]])
# Evaluate community 134
# Botnet community 8
# MCR:  0.010483651214069294 AVG_DD:  0.9085332678932774 AVG_MCR:  0.050648653102063707
# Scores:  (0.9540229885057471, 0.8383838383838383, 0.8924731182795698, [[83, 4], [16, 65433]])
# Evaluate community 148
# Botnet community 9
# MCR:  0.04491329419751349 AVG_DD:  0.8861582437041156 AVG_MCR:  0.03987205686075595
# Scores:  (0.9540229885057471, 0.8383838383838383, 0.8924731182795698, [[83, 4], [16, 65433]])
# Evaluate community 150
# Botnet community 8
# MCR:  0.05 AVG_DD:  0.8549126346867046 AVG_MCR:  0.06539820631418436
# Scores:  (0.8962264150943396, 0.9595959595959596, 0.926829268292683, [[95, 11], [4, 65426]])
# Evaluate community 150
# Botnet community 8
# MCR:  0.0498593261969661 AVG_DD:  0.8410263652515477 AVG_MCR:  0.06120136111162702
# Scores:  (0.8962264150943396, 0.9595959595959596, 0.926829268292683, [[95, 11], [4, 65426]])
# Evaluate community 124
# Botnet community 14
# MCR:  0.0010269654087891498 AVG_DD:  0.8169562747771566 AVG_MCR:  0.044377965260436796
# Scores:  (0.8558558558558559, 0.9595959595959596, 0.9047619047619048, [[95, 16], [4, 65421]])
# Evaluate community 150
# Botnet community 11
# MCR:  0.04979370679619051 AVG_DD:  0.8264981502142221 AVG_MCR:  0.050057132588261624
# Scores:  (0.8636363636363636, 0.9595959595959596, 0.9090909090909092, [[95, 15], [4, 65422]])
# Evaluate community 148
# Botnet community 12
# MCR:  0.04677569605573893 AVG_DD:  0.9014178311438412 AVG_MCR:  0.005492615539284561
# Scores:  (0.9540229885057471, 0.8383838383838383, 0.8924731182795698, [[83, 4], [16, 65433]])
# Evaluate community 148
# Botnet community 6
# MCR:  0.048041391150188385 AVG_DD:  0.9437670801370819 AVG_MCR:  0.0176362307033571
# Scores:  (0.9540229885057471, 0.8383838383838383, 0.8924731182795698, [[83, 4], [16, 65433]])
# Evaluate community 150
# Botnet community 12
# MCR:  0.05 AVG_DD:  0.8 AVG_MCR:  0.055499651382547435
# Scores:  (0.8558558558558559, 0.9595959595959596, 0.9047619047619048, [[95, 16], [4, 65421]])
# Evaluate community 127
# Botnet community 15
# MCR:  0.004089140046163691 AVG_DD:  0.8021260957705929 AVG_MCR:  0.04144286052548461
# Scores:  (0.8558558558558559, 0.9595959595959596, 0.9047619047619048, [[95, 16], [4, 65421]])
# Evaluate community 148
# Botnet community 5
# MCR:  0.04760665619618629 AVG_DD:  0.8457746371309585 AVG_MCR:  0.08839956108789654
# Scores:  (0.8962264150943396, 0.9595959595959596, 0.926829268292683, [[95, 11], [4, 65426]])
# Evaluate community 148
# Botnet community 6
# MCR:  0.04854888001689718 AVG_DD:  0.8346730972164358 AVG_MCR:  0.0880416842362422
# Scores:  (0.8962264150943396, 0.9595959595959596, 0.926829268292683, [[95, 11], [4, 65426]])
# Evaluate community 148
# Botnet community 17
# MCR:  0.047041287693799685 AVG_DD:  0.8469818232702361 AVG_MCR:  0.013683639471716837
# Scores:  (0.8636363636363636, 0.9595959595959596, 0.9090909090909092, [[95, 15], [4, 65422]])
# Evaluate community 130
# Botnet community 13
# MCR:  0.008203761604409542 AVG_DD:  0.8655440376779086 AVG_MCR:  0.03335742907615643
# Scores:  (0.8545454545454545, 0.9494949494949495, 0.8995215311004785, [[94, 16], [5, 65421]])
# Evaluate community 150
# Botnet community 5
# MCR:  0.049226869098660406 AVG_DD:  0.8764303633949825 AVG_MCR:  0.06308982539153582
# Scores:  (1.0, 0.8383838383838383, 0.9120879120879121, [[83, 0], [16, 65437]])
# Evaluate community 150
# Botnet community 10
# MCR:  0.049790440391754245 AVG_DD:  0.9286906756986932 AVG_MCR:  0.005392628320968239
# Scores:  (0.9540229885057471, 0.8383838383838383, 0.8924731182795698, [[83, 4], [16, 65433]])
# Evaluate community 126
# Botnet community 4
# MCR:  0.003589354802196104 AVG_DD:  0.8087666181246586 AVG_MCR:  0.09483921625106081
# Scores:  (0.9666666666666667, 0.8787878787878788, 0.9206349206349207, [[87, 3], [12, 65434]])
# Evaluate community 150
# Botnet community 6
# MCR:  0.04943634880071431 AVG_DD:  0.8175462471037214 AVG_MCR:  0.08887723885104451
# Scores:  (0.8962264150943396, 0.9595959595959596, 0.926829268292683, [[95, 11], [4, 65426]])
# Evaluate community 150
# Botnet community 18
# MCR:  0.04942206477837493 AVG_DD:  0.837802491113456 AVG_MCR:  0.005757301684341018
# Scores:  (0.8636363636363636, 0.9595959595959596, 0.9090909090909092, [[95, 15], [4, 65422]])
# Evaluate community 148
# Botnet community 4
# MCR:  0.047826473495835506 AVG_DD:  0.9372744706545643 AVG_MCR:  0.04288060205116592
# Scores:  (0.9540229885057471, 0.8383838383838383, 0.8924731182795698, [[83, 4], [16, 65433]])
# Evaluate community 148
# Botnet community 11
# MCR:  0.043483789796911226 AVG_DD:  0.8923158770060798 AVG_MCR:  0.029943014263679076
# Scores:  (0.9540229885057471, 0.8383838383838383, 0.8924731182795698, [[83, 4], [16, 65433]])
# Evaluate community 150
# Botnet community 4
# MCR:  0.0494831062310416 AVG_DD:  0.863708763756467 AVG_MCR:  0.07442320066210316
# Scores:  (0.8952380952380953, 0.9494949494949495, 0.9215686274509803, [[94, 11], [5, 65426]])
# Evaluate community 130
# Botnet community 11
# MCR:  0.005665196308455282 AVG_DD:  0.9121554196378845 AVG_MCR:  0.012577860952996778
# Scores:  (0.9550561797752809, 0.8585858585858586, 0.9042553191489363, [[85, 4], [14, 65433]])
# Evaluate community 150
# Botnet community 4
# MCR:  0.049957231645890283 AVG_DD:  0.8564702988467306 AVG_MCR:  0.0896146989410344
# Scores:  (0.8952380952380953, 0.9494949494949495, 0.9215686274509803, [[94, 11], [5, 65426]])
# Evaluate community 148
# Botnet community 6
# MCR:  0.04676499070886945 AVG_DD:  0.8022202390314663 AVG_MCR:  0.0897367155680051
# Scores:  (0.8962264150943396, 0.9595959595959596, 0.926829268292683, [[95, 11], [4, 65426]])
# Evaluate community 148
# Botnet community 19
# MCR:  0.04739199703338399 AVG_DD:  0.8002780134411586 AVG_MCR:  0.004284754857051366
# Scores:  (0.8558558558558559, 0.9595959595959596, 0.9047619047619048, [[95, 16], [4, 65421]])
# Evaluate community 148
# Botnet community 2
# MCR:  0.04823718509924504 AVG_DD:  0.9654989883271161 AVG_MCR:  0.01839436757583951
# Scores:  (1.0, 0.7676767676767676, 0.8685714285714284, [[76, 0], [23, 65437]])
# Evaluate community 125
# Botnet community 13
# MCR:  0.001499834307778199 AVG_DD:  0.8410266970258408 AVG_MCR:  0.04344824491499076
# Scores:  (0.8545454545454545, 0.9494949494949495, 0.8995215311004785, [[94, 16], [5, 65421]])
# Evaluate community 148
# Botnet community 18
# MCR:  0.0443149564090519 AVG_DD:  0.810876716411962 AVG_MCR:  0.015470867895455858
# Scores:  (0.8636363636363636, 0.9595959595959596, 0.9090909090909092, [[95, 15], [4, 65422]])
# Evaluate community 126
# Botnet community 13
# MCR:  0.002391015840535114 AVG_DD:  0.8916941728000031 AVG_MCR:  0.006448349723300943
# Scores:  (0.9550561797752809, 0.8585858585858586, 0.9042553191489363, [[85, 4], [14, 65433]])
# Evaluate community 150
# Botnet community 6
# MCR:  0.049891598991405925 AVG_DD:  0.8259029581634003 AVG_MCR:  0.08274554997404761
# Scores:  (0.8962264150943396, 0.9595959595959596, 0.926829268292683, [[95, 11], [4, 65426]])
# Evaluate community 125
# Botnet community 2
# MCR:  0.001397365362263764 AVG_DD:  0.9588582606463621 AVG_MCR:  0.037319923711792546
# Scores:  (1.0, 0.7676767676767676, 0.8685714285714284, [[76, 0], [23, 65437]])
# Evaluate community 126
# Botnet community 1
# MCR:  0.0026570680641311087 AVG_DD:  0.9704825523437838 AVG_MCR:  0.016560965345573914
# Scores:  (1.0, 0.5959595959595959, 0.7468354430379746, [[59, 0], [40, 65437]])

# %%
cls_gp.fun
# Out:
# np.float64(-0.9353233830845771)
